# %% [markdown]
# # Make Dataset

# %% [markdown]
# ## Imports

# %%
from PlantReactivityAnalysis.data.wav_data_reader import WavDataReader
from PlantReactivityAnalysis.data.signal_dataset import SignalDataset
from PlantReactivityAnalysis.features.wav_feature_extractor import WavFeatureExtractor
from PlantReactivityAnalysis.features.features_dataset import FeaturesDataset
import PlantReactivityAnalysis.data.preparation_eurythmy_data as ped

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Reader

# %%
wav_folder= r"..\data\raw\wav_files"
#wav_folder= r"..\data\interim\testing"

# %%
# Initialize the reader with the folder of wavs
reader= WavDataReader(folder= wav_folder, sample_rate= 10000)

# Get the signals and the keys from the reader
signals, ids= reader.get_ordered_signals_and_keys()

# Get the measurement labels from the keys of the files
meas_df= ped.return_meas_labels_by_keys(ids)
# Out:
# Total WAV files read: 625

# %%
meas_df.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  num_eurythmy
# 0               1               1  2023-04-29  salad           1             1
# 1               2               1  2023-04-29  salad           1             1
# 2               3               1  2023-04-29  salad           1             1
# 3               4               1  2023-04-29  salad           2             0
# 4               5               1  2023-04-29  salad           2             0

# %% [markdown]
# ## Signal Dataset

# %% [markdown]
# ### Raw

# %%
# Initialize SignalDataset with the signals and features/labels
signal_dataset= SignalDataset(signals= signals, features= meas_df)

# %%
signal_dataset.features.shape
# Out:
# (625, 6)

# %%
signal_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  num_eurythmy
# 0               1               1  2023-04-29  salad           1             1
# 1               2               1  2023-04-29  salad           1             1
# 2               3               1  2023-04-29  salad           1             1
# 3               4               1  2023-04-29  salad           2             0
# 4               5               1  2023-04-29  salad           2             0

# %%
# Save and Load the dataset
raw_signal_dataset_path= r"..\data\raw\raw_signal_dataset.pkl"

# %%
signal_dataset.save(raw_signal_dataset_path)
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %% [markdown]
# ### Normalized

# %%
# Standardize Signals using Zscore
signal_dataset.standardize_signals("zscore")

# %%
signal_dataset.features.shape
# Out:
# (625, 6)

# %%
# Save the dataset
norm_signal_dataset_path= r"..\data\interim\norm_signal_dataset.pkl"
signal_dataset.save(norm_signal_dataset_path)

# %% [markdown]
# ### Segmented by Letters (raw)

# %%
# Load raw dataset
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %%
# Get Letter segments from raw data
letter_dictionary= ped.return_letter_dictionary(indexes= signal_dataset.features['id_measurement'].tolist())

# %%
# Segment the dataset
signal_dataset.segment_signals_by_dict('id_measurement', letter_dictionary, 'eurythmy_letter')

# %%
signal_dataset.features.shape #8390, 7
# Out:
# (8878, 7)

# %%
signal_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter
# 0             1              A1
# 1             1              G1
# 2             1              D1
# 3             1              A2
# 4             1              G2

# %%
raw_letters_signal_dataset_path= r"..\data\raw\raw_letters_signal_dataset.pkl"

# %%
# Save the dataset
signal_dataset.save(raw_letters_signal_dataset_path)

# %% [markdown]
# ### Segmented by Letters (normalized)

# %%
# Load normalized dataset
signal_dataset= SignalDataset.load(norm_signal_dataset_path)

# %%
# Get Letter segments from raw data
letter_dictionary= ped.return_letter_dictionary(indexes= signal_dataset.features['id_measurement'].tolist())

# %%
# Segment the dataset
signal_dataset.segment_signals_by_dict('id_measurement', letter_dictionary, 'eurythmy_letter')

# %%
norm_letters_signal_dataset_path= r"..\data\interim\norm_letters_signal_dataset.pkl"

# %%
# Save the dataset
signal_dataset.save(norm_letters_signal_dataset_path)

# %% [markdown]
# ### Segmented in 1s (raw)

# %%
# Load raw dataset
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %%
# Segment Signals in 1sec segments
signal_dataset.segment_signals_by_duration(segment_duration= 1)

# %%
#Add eurythmy letter data to the features
df= ped.add_meas_letters(signal_dataset.features)

# %%
signal_dataset.features.shape
# Out:
# (148682, 8)

# %%
signal_dataset.features.iloc[15:20]
# Out:
#     id_measurement  id_performance    datetime  plant  generation  \
# 15               1               1  2023-04-29  salad           1
# 16               1               1  2023-04-29  salad           1
# 17               1               1  2023-04-29  salad           1
# 18               1               1  2023-04-29  salad           1
# 19               1               1  2023-04-29  salad           1
#
#     num_eurythmy  initial_second eurythmy_letter
# 15             1            15.0            None
# 16             1            16.0            None
# 17             1            17.0              A1
# 18             1            18.0              A1
# 19             1            19.0              A1

# %%
# Save the dataset
raw_1s_signal_dataset_path= r"..\data\raw\raw_1s_signal_dataset.pkl"
signal_dataset.save(raw_1s_signal_dataset_path)

# %% [markdown]
# ### Segmented in 1s (normalized)

# %%
# Load normalized dataset
signal_dataset= SignalDataset.load(norm_signal_dataset_path)

# %%
# Segment Signals in 1sec segments
signal_dataset.segment_signals_by_duration(segment_duration=1)

# %%
#Add eurythmy letter data to the features
df= ped.add_meas_letters(signal_dataset.features)

# %%
# Save the dataset
norm_1s_signal_dataset_path= r"..\data\interim\norm_1s_signal_dataset.pkl"
signal_dataset.save(norm_1s_signal_dataset_path)

# %% [markdown]
# ## Features Dataset

# %%
window_size= 2
hop_length= 1

feature_extractor= WavFeatureExtractor(sample_rate= 10000, lib_mfccs= True, pyau_mfccs= True, temporal= True,
                                       statistical= True, window_size= window_size, hop_length= hop_length)

# %% [markdown]
# ### Normalized letters

# %%
# Load dataset
signal_dataset= SignalDataset.load(norm_letters_signal_dataset_path)

# %%
# %%time

# Extract features and store in dataset
feat_dataset= FeaturesDataset.from_signal_dataset(signal_dataset, feature_extractor)
# Out:
# C:\Users\alvar\Documents\GitHub\Plant-Reactivity-Analysis\src\PlantReactivityAnalysis\features\wav_feature_extractor.py:297: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   feature_values.append(func(waveform_data))
# CPU times: total: 5h 11min 53s
# Wall time: 3h 54min 24s

# %%
feat_dataset.features.shape
# Out:
# (8878, 187)

# %%
feat_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter  lib_mfcc_1_avg  lib_mfcc_2_avg  \
# 0             1              A1      -23.534912       83.198769
# 1             1              G1      -81.110771       88.325844
# 2             1              D1       24.882153       89.385994
# 3             1              A2       24.231644       88.621597
# 4             1              G2      -55.030022       90.277245
#
#    lib_mfcc_3_avg  lib_mfcc_4_avg  lib_mfcc_5_avg  lib_mfcc_6_avg  \
# 0       25.629099       19.752411       14.392270       11.136339
# 1       28.627588       24.234732       17.512836       14.781477
# 2       26.346279       23.596043       16.545910       13.589697
# 3       25.669394       22.936642       15.933237       13.037097
# 4       27.136541       24.391529       17.351828       14.491565
#
#    lib_mfcc_7_avg  lib_mfcc_8_avg  lib_mfcc_9_avg  lib_mfcc_10_avg  \
# 0        9.130905        9.132786        9.201151         8.549523
# 1       11.906365       10.436690        9.275619         8.338777
# 2       10.682384        9.265663        8.128407         7.406046
# 3       10.171865        8.814935        7.888070         7.525625
# 4       11.674594       10.279722        9.026291         8.241884
#
#    lib_mfcc_11_avg  lib_mfcc_12_avg  lib_mfcc_13_avg  lib_mfcc_1_std  \
# 0         7.044505         6.178267         5.965608       94.381187
# 1         7.319038         6.788760         6.659635      107.915901
# 2         6.642943         6.148542         5.691988       59.993217
# 3         6.835879         6.082570         5.667099       49.872616
# 4         7.445746         6.870279         6.332922       85.320297
#
#    lib_mfcc_2_std  lib_mfcc_3_std  lib_mfcc_4_std  lib_mfcc_5_std  \
# 0        5.893996        7.979805        4.722373        5.581942
# 1        5.592562        4.527091        0.873110        0.960102
# 2        0.354342        0.350243        0.370835        0.302728
# 3        2.093105        1.765709        1.699441        1.610318
# 4        0.771419        0.725948        0.723136        0.727420
#
#    lib_mfcc_6_std  lib_mfcc_7_std  lib_mfcc_8_std  lib_mfcc_9_std  \
# 0        4.857383        3.813931        2.075639        1.897661
# 1        1.345174        1.155145        0.981901        1.173628
# 2        0.327575        0.431741        0.538075        0.620608
# 3        1.539667        1.553005        1.327099        0.530647
# 4        0.716087        0.715486        0.723956        0.737132
#
#    lib_mfcc_10_std  lib_mfcc_11_std  lib_mfcc_12_std  lib_mfcc_13_std  \
# 0         1.554459         1.101802         1.844000         1.201164
# 1         1.252299         1.431759         1.505018         1.125069
# 2         0.436250         0.336217         0.356718         0.557945
# 3         0.567084         0.853385         0.550213         0.553980
# 4         0.731813         0.724335         0.721453         0.728042
#
#    zcr_mean  energy_mean  energy_entropy_mean  spectral_centroid_mean  \
# 0  0.000039     0.088293             3.261156                0.032339
# 1  0.000067     0.036979             3.247725                0.031531
# 2  0.000100     0.202628             3.248218                0.045630
# 3  0.000067     0.130958             3.246399                0.042626
# 4  0.000028     0.135860             3.299588                0.021953
#
#    spectral_spread_mean  spectral_entropy_mean  spectral_flux_mean  \
# 0              0.081496               0.004831            0.018852
# 1              0.065249               0.008275            0.060365
# 2              0.128851               0.008015            0.026937
# 3              0.120713               0.006644            0.023050
# 4              0.057486               0.003281            0.019302
#
#    spectral_rolloff_mean  mfcc_1_mean  mfcc_2_mean  mfcc_3_mean  mfcc_4_mean  \
# 0               0.000211   -62.109250     1.242231     0.156427     0.212559
# 1               0.000511   -74.022181     0.832606     0.101700     0.142790
# 2               0.000578   -35.315901     2.103270     0.265058     0.371516
# 3               0.000389   -37.588270     2.108827     0.263524     0.373077
# 4               0.000233   -69.933370     0.968435     0.105019     0.168915
#
#    mfcc_5_mean  mfcc_6_mean  mfcc_7_mean  mfcc_8_mean  mfcc_9_mean  \
# 0     0.093449     0.103613     0.062251     0.059889     0.036835
# 1     0.060989     0.076810     0.042051     0.041954     0.031592
# 2     0.174430     0.190836     0.091169     0.087125     0.052937
# 3     0.164793     0.171458     0.093967     0.097220     0.054322
# 4     0.075515     0.083570     0.041228     0.040927     0.031488
#
#    mfcc_10_mean  mfcc_11_mean  mfcc_12_mean  mfcc_13_mean  chroma_1_mean  \
# 0      0.030198      0.018111      0.026666      0.015780       0.000044
# 1      0.042674      0.024715      0.020495      0.005546       0.000076
# 2      0.074836      0.043423      0.050004      0.044027       0.000057
# 3      0.058412      0.042166      0.051357      0.036084       0.000064
# 4      0.026295      0.017951      0.023164      0.021055       0.000044
#
#    chroma_2_mean  chroma_3_mean  chroma_4_mean  chroma_5_mean  chroma_6_mean  \
# 0       0.000008       0.001371       0.000043       0.196795       0.000024
# 1       0.000014       0.003797       0.000054       0.194430       0.000039
# 2       0.000013       0.002173       0.000068       0.194083       0.000056
# 3       0.000011       0.001602       0.000040       0.195005       0.000030
# 4       0.000004       0.001049       0.000020       0.197668       0.000012
#
#    chroma_7_mean  chroma_8_mean  chroma_9_mean  chroma_10_mean  \
# 0       0.005584       0.000003       0.000010        0.000034
# 1       0.008414       0.000008       0.000020        0.000117
# 2       0.010790       0.000007       0.000020        0.000056
# 3       0.009612       0.000006       0.000017        0.000060
# 4       0.004087       0.000003       0.000009        0.000026
#
#    chroma_11_mean  chroma_12_mean  chroma_std_mean  delta zcr_mean  \
# 0        0.000326        0.000012         0.054775             0.0
# 1        0.000399        0.000020         0.054907             0.0
# 2        0.000567        0.000015         0.055196             0.0
# 3        0.000309        0.000014         0.054725             0.0
# 4        0.000189        0.000004         0.055324             0.0
#
#    delta energy_mean  delta energy_entropy_mean  delta spectral_centroid_mean  \
# 0          -0.000083                  -0.001171                      0.000653
# 1          -0.002814                  -0.000501                      0.000308
# 2           0.001532                   0.000494                     -0.000354
# 3          -0.001233                   0.000568                     -0.000345
# 4          -0.001958                   0.000058                     -0.000156
#
#    delta spectral_spread_mean  delta spectral_entropy_mean  \
# 0                    0.001579                     0.000068
# 1                    0.000752                     0.000026
# 2                   -0.000408                    -0.000088
# 3                   -0.001109                    -0.000029
# 4                   -0.000655                    -0.000005
#
#    delta spectral_flux_mean  delta spectral_rolloff_mean  delta mfcc_1_mean  \
# 0                  0.000363                          0.0           0.580328
# 1                  0.001228                          0.0           0.180828
# 2                 -0.000211                          0.0           0.011734
# 3                  0.000045                          0.0          -0.562003
# 4                 -0.000124                          0.0          -0.380340
#
#    delta mfcc_2_mean  delta mfcc_3_mean  delta mfcc_4_mean  delta mfcc_5_mean  \
# 0           0.019567           0.002610           0.003520           0.001203
# 1           0.006731           0.000876           0.001314           0.000844
# 2          -0.000325          -0.000596           0.000300           0.000138
# 3          -0.019236          -0.003142          -0.005041          -0.002442
# 4          -0.012666          -0.001630          -0.002312          -0.000983
#
#    delta mfcc_6_mean  delta mfcc_7_mean  delta mfcc_8_mean  delta mfcc_9_mean  \
# 0           0.000764          -0.000157           0.000929           0.000994
# 1           0.000926           0.000632           0.000717           0.000514
# 2           0.000972           0.002798           0.002181          -0.001121
# 3          -0.001331          -0.000573          -0.000474           0.000158
# 4          -0.000489           0.000185          -0.000142          -0.000612
#
#    delta mfcc_10_mean  delta mfcc_11_mean  delta mfcc_12_mean  \
# 0            0.000307           -0.000145            0.000688
# 1            0.000240            0.000155            0.000245
# 2           -0.002047           -0.001878            0.001422
# 3           -0.001223            0.000037           -0.000513
# 4           -0.000225            0.000228           -0.000228
#
#    delta mfcc_13_mean  delta chroma_1_mean  delta chroma_2_mean  \
# 0            0.000013         9.071631e-07         1.274990e-07
# 1            0.000198         4.550032e-07        -8.178217e-09
# 2            0.000613        -8.747123e-07        -7.184711e-08
# 3           -0.000303        -1.050935e-07        -4.277174e-08
# 4           -0.000296        -1.173815e-08        -7.263613e-09
#
#    delta chroma_3_mean  delta chroma_4_mean  delta chroma_5_mean  \
# 0             0.000015         1.650146e-07            -0.000045
# 1             0.000017         8.616054e-08            -0.000017
# 2            -0.000006        -6.571800e-07             0.000022
# 3            -0.000005        -3.054473e-07             0.000022
# 4            -0.000001        -3.558277e-08             0.000002
#
#    delta chroma_6_mean  delta chroma_7_mean  delta chroma_8_mean  \
# 0         2.736884e-07             0.000086         6.399836e-08
# 1         6.400987e-08             0.000025         5.656602e-08
# 2        -4.953710e-07            -0.000036        -9.587337e-08
# 3        -8.393800e-08            -0.000047        -1.860274e-08
# 4        -7.830720e-09            -0.000003        -4.158123e-09
#
#    delta chroma_9_mean  delta chroma_10_mean  delta chroma_11_mean  \
# 0         2.250915e-07          6.739145e-07          2.442303e-06
# 1         2.393033e-08         -1.954098e-07         -2.146093e-07
# 2        -3.009933e-07         -7.334357e-07         -1.241162e-06
# 3        -4.955292e-08         -2.239235e-07         -1.072793e-06
# 4        -8.823139e-09         -5.195987e-08         -8.967604e-08
#
#    delta chroma_12_mean  delta chroma_std_mean   zcr_std  energy_std  \
# 0          1.371131e-07          -1.453088e-05  0.000222    0.077577
# 1          2.483693e-08          -5.714218e-06  0.000278    0.037703
# 2         -1.663212e-07           6.846981e-06  0.000401    0.177835
# 3         -4.986739e-08           7.047755e-06  0.000226    0.110940
# 4         -2.177257e-09           6.608713e-07  0.000153    0.093842
#
#    energy_entropy_std  spectral_centroid_std  spectral_spread_std  \
# 0            0.136340               0.026048             0.059164
# 1            0.163475               0.035331             0.077949
# 2            0.176057               0.030787             0.049501
# 3            0.133441               0.029652             0.052113
# 4            0.056375               0.024274             0.059307
#
#    spectral_entropy_std  spectral_flux_std  spectral_rolloff_std  mfcc_1_std  \
# 0              0.015137           0.034235              0.001276   24.297230
# 1              0.020320           0.096558              0.001798   29.464559
# 2              0.022487           0.044192              0.002322   15.144790
# 3              0.014303           0.041577              0.001422   17.326778
# 4              0.011812           0.037042              0.001120   26.467828
#
#    mfcc_2_std  mfcc_3_std  mfcc_4_std  mfcc_5_std  mfcc_6_std  mfcc_7_std  \
# 0    0.838808    0.126133    0.165385    0.092794    0.109901    0.072774
# 1    0.993798    0.140181    0.190954    0.108714    0.101863    0.088546
# 2    0.536593    0.159475    0.168653    0.126814    0.107653    0.130092
# 3    0.597061    0.123058    0.134881    0.098827    0.106716    0.090826
# 4    0.886959    0.141665    0.170428    0.083581    0.093652    0.077100
#
#    mfcc_8_std  mfcc_9_std  mfcc_10_std  mfcc_11_std  mfcc_12_std  mfcc_13_std  \
# 0    0.093840    0.065705     0.072746     0.071245     0.068011     0.067845
# 1    0.097048    0.077290     0.099240     0.094032     0.080031     0.077644
# 2    0.138037    0.135007     0.133202     0.125984     0.110877     0.105254
# 3    0.105030    0.101068     0.116089     0.101743     0.094099     0.084965
# 4    0.061025    0.059212     0.058035     0.055242     0.051118     0.046122
#
#    chroma_1_std  chroma_2_std  chroma_3_std  chroma_4_std  chroma_5_std  \
# 0      0.000174      0.000031      0.005554      0.000178      0.010334
# 1      0.000245      0.000036      0.012263      0.000156      0.014731
# 2      0.000180      0.000049      0.006867      0.000254      0.018759
# 3      0.000187      0.000028      0.004392      0.000110      0.012520
# 4      0.000216      0.000014      0.004280      0.000075      0.010616
#
#    chroma_6_std  chroma_7_std  chroma_8_std  chroma_9_std  chroma_10_std  \
# 0      0.000097      0.016180      0.000008      0.000030       0.000090
# 1      0.000140      0.020650      0.000023      0.000054       0.000308
# 2      0.000205      0.034613      0.000026      0.000059       0.000155
# 3      0.000084      0.024307      0.000015      0.000045       0.000153
# 4      0.000047      0.019414      0.000013      0.000039       0.000092
#
#    chroma_11_std  chroma_12_std  chroma_std_std  delta zcr_std  \
# 0       0.001466       0.000049        0.000916       0.000319
# 1       0.001101       0.000059        0.001867       0.000406
# 2       0.001983       0.000050        0.003913       0.000528
# 3       0.000809       0.000034        0.002307       0.000277
# 4       0.000895       0.000015        0.002376       0.000220
#
#    delta energy_std  delta energy_entropy_std  delta spectral_centroid_std  \
# 0          0.057773                  0.161315                     0.023138
# 1          0.011726                  0.219100                     0.040969
# 2          0.079925                  0.190558                     0.027738
# 3          0.041242                  0.144102                     0.024714
# 4          0.029749                  0.056299                     0.022645
#
#    delta spectral_spread_std  delta spectral_entropy_std  \
# 0                   0.050035                    0.019565
# 1                   0.090714                    0.027827
# 2                   0.054177                    0.025826
# 3                   0.048307                    0.017029
# 4                   0.067458                    0.014334
#
#    delta spectral_flux_std  delta spectral_rolloff_std  delta mfcc_1_std  \
# 0                 0.039680                    0.001830         22.312091
# 1                 0.128605                    0.002586         33.777046
# 2                 0.055053                    0.002919         22.322038
# 3                 0.047357                    0.002055         22.534897
# 4                 0.038483                    0.001456         33.716587
#
#    delta mfcc_2_std  delta mfcc_3_std  delta mfcc_4_std  delta mfcc_5_std  \
# 0          0.801896          0.134204          0.165630          0.106375
# 1          1.148502          0.170788          0.221685          0.136440
# 2          0.792940          0.235095          0.251321          0.186034
# 3          0.786018          0.164293          0.177738          0.141664
# 4          1.143247          0.199484          0.222639          0.108690
#
#    delta mfcc_6_std  delta mfcc_7_std  delta mfcc_8_std  delta mfcc_9_std  \
# 0          0.139996          0.096830          0.121030          0.087582
# 1          0.128271          0.127941          0.129519          0.108880
# 2          0.155704          0.187763          0.193832          0.188132
# 3          0.165959          0.126755          0.147267          0.146208
# 4          0.119317          0.104247          0.082896          0.083608
#
#    delta mfcc_10_std  delta mfcc_11_std  delta mfcc_12_std  delta mfcc_13_std  \
# 0           0.099202           0.101545           0.092924           0.097668
# 1           0.140506           0.132047           0.107975           0.108990
# 2           0.191871           0.188995           0.162429           0.149996
# 3           0.152000           0.151599           0.127924           0.116298
# 4           0.081615           0.075996           0.072731           0.065632
#
#    delta chroma_1_std  delta chroma_2_std  delta chroma_3_std  \
# 0            0.000231            0.000043            0.007664
# 1            0.000349            0.000048            0.017193
# 2            0.000219            0.000064            0.008311
# 3            0.000247            0.000038            0.005974
# 4            0.000296            0.000016            0.005429
#
#    delta chroma_4_std  delta chroma_5_std  delta chroma_6_std  \
# 0            0.000234            0.013436            0.000132
# 1            0.000213            0.020766            0.000201
# 2            0.000323            0.021651            0.000266
# 3            0.000148            0.016070            0.000110
# 4            0.000091            0.014310            0.000062
#
#    delta chroma_7_std  delta chroma_8_std  delta chroma_9_std  \
# 0            0.020331            0.000011            0.000037
# 1            0.029278            0.000032            0.000077
# 2            0.040057            0.000034            0.000072
# 3            0.031242            0.000018            0.000058
# 4            0.026611            0.000017            0.000050
#
#    delta chroma_10_std  delta chroma_11_std  delta chroma_12_std  \
# 0             0.000110             0.002048             0.000065
# 1             0.000422             0.001522             0.000084
# 2             0.000190             0.002374             0.000060
# 3             0.000187             0.001058             0.000042
# 4             0.000112             0.001188             0.000019
#
#    delta chroma_std_std  zero_crossing_rate  root_mean_square_energy  \
# 0              0.001063            0.000017                 1.443897
# 1              0.002694            0.000006                 0.732309
# 2              0.005729            0.000033                 1.401224
# 3              0.002879            0.000067                 1.631849
# 4              0.003305            0.000017                 0.771450
#
#    slope_sign_changes_ratio  duration_seconds  flatness_ratio_10000  \
# 0                  0.018133               9.0              0.352622
# 1                  0.002644               9.0              0.328122
# 2                  0.010444               9.0              0.000000
# 3                  0.012356               9.0              0.000000
# 4                  0.003511               9.0              0.111556
#
#    flatness_ratio_5000  flatness_ratio_1000  flatness_ratio_500  \
# 0             0.352622             0.536244            0.616367
# 1             0.328122             0.688267            0.812756
# 2             0.000000             0.039000            0.279922
# 3             0.000000             0.053656            0.217267
# 4             0.334178             0.604156            0.740889
#
#    flatness_ratio_100  hjorth_mobility  hjorth_complexity      mean  variance  \
# 0            0.774433         0.000017       80464.145670 -0.069488  2.080011
# 1            0.982800         0.000021       54194.021625  0.579218  0.200783
# 2            0.871789         0.000020       59588.992615 -1.019622  0.923799
# 3            0.848300         0.000015       87704.209952 -0.912563  1.830160
# 4            0.978600         0.000022       52998.819272  0.371457  0.457155
#
#    standard_deviation  interquartile_range  skewness  kurtosis       dfa
# 0            1.442224             1.082166 -1.651490  1.428384  1.652581
# 1            0.448089             0.144289 -2.380866  4.743071  1.640983
# 2            0.961145             1.515033 -0.104159 -0.900896  1.679972
# 3            1.352834             1.442888 -1.178505  0.668149  1.672634
# 4            0.676132             0.577155 -1.348706  0.188683  1.734061

# %%
# Save the dataset
feat_norm_letters_dataset_path= r"..\data\processed\feat_norm_letters_" + str(window_size) + "_" + str(hop_length) + "_dataset.pkl"
feat_dataset.save(feat_norm_letters_dataset_path)

# %% [markdown]
# ### Letters

# %%
# Load dataset
signal_dataset= SignalDataset.load(raw_letters_signal_dataset_path)

# %%
# %%time

# Extract features and store in dataset
feat_dataset= FeaturesDataset.from_signal_dataset(signal_dataset, feature_extractor)
# Out:
# C:\Users\alvar\Documents\GitHub\Plant-Reactivity-Analysis\src\PlantReactivityAnalysis\features\wav_feature_extractor.py:297: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   feature_values.append(func(waveform_data))
# CPU times: total: 5h 23min 59s
# Wall time: 9h 54min 16s

# %%
# Save the dataset
feat_raw_letters_dataset_path= r"..\data\processed\feat_raw_letters_" + str(window_size) + "_" + str(hop_length) + "_dataset.pkl"
feat_dataset.save(feat_raw_letters_dataset_path)
