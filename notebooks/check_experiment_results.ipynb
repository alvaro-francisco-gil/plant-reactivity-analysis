# %%
from PlantReactivityAnalysis.config import FEATURES_LETTERS_DIR, FIGURES_DIR
from PlantReactivityAnalysis.visualization.visualize import export_df_to_image_formatted

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
file_path = r"experiment_results.csv"
df = pd.read_csv(file_path)
df.shape
# Out:
# (1863, 11)

# %%
df['Hop Length'].value_counts()
# Out:
# Hop Length
# 1.00    828
# 0.50    414
# 2.00    414
# 0.10    138
# 0.05     69
# Name: count, dtype: int64

# %%
df['Window Size'].value_counts()
# Out:
# Window Size
# 1.0    828
# 2.0    828
# 0.1    138
# 0.2     69
# Name: count, dtype: int64

# %% [markdown]
# # RQ2 All datasets

# %%
df_rq_2 = df[df['RQ'] == 2]
best_accuracy_per_rq_dataset = df_rq_2.loc[df_rq_2.groupby(['RQ'])['accuracy'].idxmax()]
df_rq_2.reset_index(drop=True, inplace=True)
best_accuracy_per_rq_dataset.head(30)
# Out:
#             model_name  \
# 1336  gradientboosting
#
#                                                                             parameters  \
# 1336  {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'random_state': 42}
#
#             f1  accuracy  precision    recall  \
# 1336  0.453625  0.458564   0.453921  0.458564
#
#                                      confusion_matrix  RQ  Window Size  \
# 1336  [[ 95  68  88]\n [ 49 142  42]\n [ 72  73  95]]   2          1.0
#
#       Hop Length  Correlation Treshold
# 1336         1.0                   0.9

# %%
max_accuracy_index = df_rq_2['accuracy'].idxmax()
max_accuracy_row_dict = df_rq_2.iloc[max_accuracy_index].to_dict()
print(max_accuracy_row_dict)
# Out:
# {'model_name': 'gradientboosting', 'parameters': "{'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'random_state': 42}", 'f1': 0.453625332256142, 'accuracy': 0.4585635359116022, 'precision': 0.4539205975541948, 'recall': 0.4585635359116022, 'confusion_matrix': '[[ 95  68  88]\n [ 49 142  42]\n [ 72  73  95]]', 'RQ': 2, 'Window Size': 1.0, 'Hop Length': 1.0, 'Correlation Treshold': 0.9}

# %%
filtered_df = df[df['RQ'] == 2]
idx = filtered_df.groupby('model_name')['accuracy'].idxmax()
best_combinations = filtered_df.loc[idx]
columns= ['model_name', 'Window Size', 'Hop Length', 'Correlation Treshold', 'parameters', 'f1', 'accuracy', 'precision', 'recall']
best_combinations= best_combinations[columns]
column_names= ['Model', 'Window Size', 'Hop Length', 'Correlation Treshold', 'Model Parameters', 'F1', 'Accuracy', 'Precision', 'Recall']
best_combinations.columns= column_names
best_combinations.head(10)
# Out:
#                    Model  Window Size  Hop Length  Correlation Treshold  \
# 1349            adaboost          1.0         1.0                   0.9
# 1200          extratrees          1.0         0.5                   0.9
# 1347          gaussiannb          1.0         1.0                   0.9
# 1336    gradientboosting          1.0         1.0                   0.9
# 120           kneighbors          1.0         0.5                   0.7
# 1230                lgbm          1.0         0.5                   0.9
# 800   logisticregression          1.0         1.0                   0.8
# 1177        randomforest          1.0         0.5                   0.9
# 1376                 xgb          1.0         1.0                   0.9
#
#                                                                           Model Parameters  \
# 1349                       {'learning_rate': 0.1, 'n_estimators': 100, 'random_state': 42}
# 1200  {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200, 'random_state': 42}
# 1347                                                              {'var_smoothing': 1e-10}
# 1336      {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'random_state': 42}
# 120                                              {'n_neighbors': 15, 'weights': 'uniform'}
# 1230    {'learning_rate': 0.05, 'n_estimators': 100, 'num_leaves': 31, 'random_state': 42}
# 800                                  {'C': 0.1, 'solver': 'liblinear', 'random_state': 42}
# 1177  {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200, 'random_state': 42}
# 1376      {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'random_state': 42}
#
#             F1  Accuracy  Precision    Recall
# 1349  0.438793  0.439227   0.441472  0.439227
# 1200  0.434937  0.439227   0.436259  0.439227
# 1347  0.418604  0.418508   0.419201  0.418508
# 1336  0.453625  0.458564   0.453921  0.458564
# 120   0.373377  0.375691   0.375027  0.375691
# 1230  0.432006  0.435083   0.430682  0.435083
# 800   0.298383  0.374309   0.249567  0.374309
# 1177  0.444395  0.447514   0.443453  0.447514
# 1376  0.453441  0.455801   0.452967  0.455801

# %%
col_widths = [0.05, 0.05, 0.05, 0.05, 0.2, 0.05, 0.05, 0.05, 0.05] 
#export_df_to_image_formatted(best_combinations, FIGURES_DIR/'models_performance_rq2.png', figsize=(10,20), col_widths=col_widths,  font_size=100)

# %% [markdown]
# # RQ1 All datasets

# %%
df_rq_1 = df[df['RQ'] == 1]
best_accuracy_per_rq_dataset = df_rq_1.loc[df_rq_1.groupby(['RQ'])['accuracy'].idxmax()]
df_rq_1.reset_index(drop=True, inplace=True)
best_accuracy_per_rq_dataset.head(30)
# Out:
#      model_name  \
# 1436       lgbm
#
#                                                                              parameters  \
# 1436  {'learning_rate': 0.1, 'n_estimators': 200, 'num_leaves': 64, 'random_state': 42}
#
#             f1  accuracy  precision    recall         confusion_matrix  RQ  \
# 1436  0.748755  0.749421   0.752096  0.749421  [[603 261]\n [172 692]]   1
#
#       Window Size  Hop Length  Correlation Treshold
# 1436          2.0         1.0                   0.9

# %%
max_accuracy_index = df_rq_1['accuracy'].idxmax()
max_accuracy_row_dict = df_rq_1.iloc[max_accuracy_index].to_dict()
print(max_accuracy_row_dict)
# Out:
# {'model_name': 'lgbm', 'parameters': "{'learning_rate': 0.1, 'n_estimators': 200, 'num_leaves': 64, 'random_state': 42}", 'f1': 0.7487548114328004, 'accuracy': 0.7494212962962963, 'precision': 0.7520962664590597, 'recall': 0.7494212962962963, 'confusion_matrix': '[[603 261]\n [172 692]]', 'RQ': 1, 'Window Size': 2.0, 'Hop Length': 1.0, 'Correlation Treshold': 0.9}

# %%
filtered_df = df[df['RQ'] == 1]
idx = filtered_df.groupby('model_name')['accuracy'].idxmax()
best_combinations = filtered_df.loc[idx]
columns= ['model_name', 'Window Size', 'Hop Length', 'Correlation Treshold', 'parameters', 'f1', 'accuracy', 'precision', 'recall']
best_combinations= best_combinations[columns]
column_names= ['Model', 'Window Size', 'Hop Length', 'Correlation Treshold', 'Model Parameters', 'F1', 'Accuracy', 'Precision', 'Recall']
best_combinations.columns= column_names
best_combinations.head(10)
# Out:
#                    Model  Window Size  Hop Length  Correlation Treshold  \
# 1418            adaboost          2.0         1.0                   0.9
# 167           extratrees          1.0         1.0                   0.7
# 174           gaussiannb          1.0         1.0                   0.7
# 1405    gradientboosting          2.0         1.0                   0.9
# 47            kneighbors          1.0         0.5                   0.7
# 1436                lgbm          2.0         1.0                   0.9
# 41    logisticregression          1.0         0.5                   0.7
# 690         randomforest          1.0         1.0                   0.8
# 1448                 xgb          2.0         1.0                   0.9
#
#                                                                           Model Parameters  \
# 1418                       {'learning_rate': 0.1, 'n_estimators': 100, 'random_state': 42}
# 167   {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200, 'random_state': 42}
# 174                                                               {'var_smoothing': 1e-10}
# 1405      {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'random_state': 42}
# 47                                                {'n_neighbors': 5, 'weights': 'uniform'}
# 1436     {'learning_rate': 0.1, 'n_estimators': 200, 'num_leaves': 64, 'random_state': 42}
# 41                                   {'C': 0.1, 'solver': 'liblinear', 'random_state': 42}
# 690   {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 1448      {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 200, 'random_state': 42}
#
#             F1  Accuracy  Precision    Recall
# 1418  0.713397  0.715278   0.721083  0.715278
# 167   0.725075  0.725694   0.727746  0.725694
# 174   0.453119  0.526042   0.555808  0.526042
# 1405  0.738875  0.739583   0.742211  0.739583
# 47    0.517854  0.517940   0.517953  0.517940
# 1436  0.748755  0.749421   0.752096  0.749421
# 41    0.333333  0.500000   0.250000  0.500000
# 690   0.733731  0.734375   0.736666  0.734375
# 1448  0.738145  0.739005   0.742184  0.739005

# %% [markdown]
# # RQ5 All datasets

# %%
df_rq_5 = df[df['RQ'] == 5]
best_accuracy_per_rq_dataset = df_rq_5.loc[df_rq_5.groupby(['RQ'])['accuracy'].idxmax()]
df_rq_5.reset_index(drop=True, inplace=True)
best_accuracy_per_rq_dataset.head(30)
# Out:
#      model_name  \
# 1858        xgb
#
#                                                                            parameters  \
# 1858  {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'random_state': 42}
#
#             f1  accuracy  precision    recall  \
# 1858  0.505096  0.508403   0.510755  0.508403
#
#                                               confusion_matrix  RQ  \
# 1858  [[5079 3182 1415]\n [2464 5467 1322]\n [2513 2297 3098]]   5
#
#       Window Size  Hop Length  Correlation Treshold
# 1858          0.2         0.1                   0.8

# %%
max_accuracy_index = df_rq_5['accuracy'].idxmax()
max_accuracy_row_dict = df_rq_5.iloc[max_accuracy_index].to_dict()
print(max_accuracy_row_dict)
# Out:
# {'model_name': 'xgb', 'parameters': "{'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'random_state': 42}", 'f1': 0.5050963121922322, 'accuracy': 0.5084025785296419, 'precision': 0.5107548169942433, 'recall': 0.5084025785296419, 'confusion_matrix': '[[5079 3182 1415]\n [2464 5467 1322]\n [2513 2297 3098]]', 'RQ': 5, 'Window Size': 0.2, 'Hop Length': 0.1, 'Correlation Treshold': 0.8}

# %%
filtered_df = df[df['RQ'] == 5]
idx = filtered_df.groupby('model_name')['accuracy'].idxmax()
best_combinations = filtered_df.loc[idx]
columns= ['model_name', 'Window Size', 'Hop Length', 'Correlation Treshold', 'parameters', 'f1', 'accuracy', 'precision', 'recall']
best_combinations= best_combinations[columns]
column_names= ['Model', 'Window Size', 'Hop Length', 'Correlation Treshold', 'Model Parameters', 'F1', 'Accuracy', 'Precision', 'Recall']
best_combinations.columns= column_names
best_combinations.head(10)
# Out:
#                    Model  Window Size  Hop Length  Correlation Treshold  \
# 1834            adaboost          0.2         0.1                   0.8
# 1823          extratrees          0.2         0.1                   0.8
# 1830          gaussiannb          0.2         0.1                   0.8
# 1815    gradientboosting          0.2         0.1                   0.8
# 1841          kneighbors          0.2         0.1                   0.8
# 1850                lgbm          0.2         0.1                   0.8
# 1835  logisticregression          0.2         0.1                   0.8
# 1808        randomforest          0.2         0.1                   0.8
# 1858                 xgb          0.2         0.1                   0.8
#
#                                                                           Model Parameters  \
# 1834                       {'learning_rate': 1.0, 'n_estimators': 100, 'random_state': 42}
# 1823  {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200, 'random_state': 42}
# 1830                                                              {'var_smoothing': 1e-10}
# 1815       {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'random_state': 42}
# 1841                                              {'n_neighbors': 5, 'weights': 'uniform'}
# 1850     {'learning_rate': 0.1, 'n_estimators': 200, 'num_leaves': 64, 'random_state': 42}
# 1835                                 {'C': 0.1, 'solver': 'liblinear', 'random_state': 42}
# 1808    {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 300, 'random_state': 42}
# 1858       {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'random_state': 42}
#
#             F1  Accuracy  Precision    Recall
# 1834  0.413649  0.418005   0.418555  0.418005
# 1823  0.422491  0.429966   0.435450  0.429966
# 1830  0.269474  0.364571   0.382107  0.364571
# 1815  0.494918  0.498118   0.500476  0.498118
# 1841  0.338227  0.351492   0.344342  0.351492
# 1850  0.484999  0.486828   0.488105  0.486828
# 1835  0.299158  0.368558   0.343257  0.368558
# 1808  0.447380  0.453441   0.460016  0.453441
# 1858  0.505096  0.508403   0.510755  0.508403

# %%
filtered_df = df[(df['Dataset'] == 4) & (df['RQ'] == 1)]
idx = filtered_df.groupby('model_name')['accuracy'].idxmax()
best_combinations = filtered_df.loc[idx]
columns= ['model_name', 'Window Size', 'Hop Length', 'Correlation Treshold', 'parameters', 'f1', 'accuracy', 'precision', 'recall']
best_combinations= best_combinations[columns]
column_names= ['Model', 'Window Size', 'Hop Length', 'Correlation Treshold', 'Model Parameters', 'F1', 'Accuracy', 'Precision', 'Recall']
best_combinations.columns= column_names
best_combinations.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\Plant-Reactivity-Analysis\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Dataset'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 filtered_df = df[(df['Dataset'] == 4) & (df['RQ'] == 1)]
#       2 idx = filtered_df.groupby('model_name')['accuracy'].idxmax()
#       3 best_combinations = filtered_df.loc[idx]
#
# File ~\anaconda3\envs\Plant-Reactivity-Analysis\lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\anaconda3\envs\Plant-Reactivity-Analysis\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Dataset'
