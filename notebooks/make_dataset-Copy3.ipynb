# %% [markdown]
# # Make Dataset

# %% [markdown]
# ## Imports

# %%
from PlantReactivityAnalysis.data.wav_data_reader import WavDataReader
from PlantReactivityAnalysis.data.signal_dataset import SignalDataset
from PlantReactivityAnalysis.features.wav_feature_extractor import WavFeatureExtractor
from PlantReactivityAnalysis.features.features_dataset import FeaturesDataset
import PlantReactivityAnalysis.data.preparation_eurythmy_data as ped

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Reader

# %%
wav_folder= r"..\data\raw\wav_files"
#wav_folder= r"..\data\interim\testing"

# %%
# Initialize the reader with the folder of wavs
reader= WavDataReader(folder= wav_folder, sample_rate= 10000)

# Get the signals and the keys from the reader
signals, ids= reader.get_ordered_signals_and_keys()

# Get the measurement labels from the keys of the files
meas_df= ped.return_meas_labels_by_keys(ids)
# Out:
# Total WAV files read: 625

# %%
meas_df.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  num_eurythmy
# 0               1               1  2023-04-29  salad           1             1
# 1               2               1  2023-04-29  salad           1             1
# 2               3               1  2023-04-29  salad           1             1
# 3               4               1  2023-04-29  salad           2             0
# 4               5               1  2023-04-29  salad           2             0

# %% [markdown]
# ## Signal Dataset

# %% [markdown]
# ### Raw

# %%
# Initialize SignalDataset with the signals and features/labels
signal_dataset= SignalDataset(signals= signals, features= meas_df)

# %%
signal_dataset.features.shape
# Out:
# (625, 6)

# %%
signal_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  num_eurythmy
# 0               1               1  2023-04-29  salad           1             1
# 1               2               1  2023-04-29  salad           1             1
# 2               3               1  2023-04-29  salad           1             1
# 3               4               1  2023-04-29  salad           2             0
# 4               5               1  2023-04-29  salad           2             0

# %%
# Save and Load the dataset
raw_signal_dataset_path= r"..\data\raw\raw_signal_dataset.pkl"

# %%
signal_dataset.save(raw_signal_dataset_path)
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %% [markdown]
# ### Normalized

# %%
# Standardize Signals using Zscore
signal_dataset.standardize_signals("zscore")

# %%
signal_dataset.features.shape
# Out:
# (625, 6)

# %%
# Save the dataset
norm_signal_dataset_path= r"..\data\interim\norm_signal_dataset.pkl"
signal_dataset.save(norm_signal_dataset_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Save the dataset
#       2 norm_signal_dataset_path= r"..\data\interim\norm_signal_dataset.pkl"
# ----> 3 signal_dataset.save(norm_signal_dataset_path)
#
# NameError: name 'signal_dataset' is not defined

# %% [markdown]
# ### Segmented by Letters (raw)

# %%
# Load raw dataset
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %%
# Get Letter segments from raw data
letter_dictionary= ped.return_letter_dictionary(indexes= signal_dataset.features['id_measurement'].tolist())

# %%
# Segment the dataset
signal_dataset.segment_signals_by_dict('id_measurement', letter_dictionary, 'eurythmy_letter')

# %%
signal_dataset.features.shape #8390, 7
# Out:
# (8878, 7)

# %%
signal_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter
# 0             1              A1
# 1             1              G1
# 2             1              D1
# 3             1              A2
# 4             1              G2

# %%
raw_letters_signal_dataset_path= r"..\data\raw\raw_letters_signal_dataset.pkl"

# %%
# Save the dataset
signal_dataset.save(raw_letters_signal_dataset_path)

# %% [markdown]
# ### Segmented by Letters (normalized)

# %%
# Load normalized dataset
signal_dataset= SignalDataset.load(norm_signal_dataset_path)

# %%
# Get Letter segments from raw data
letter_dictionary= ped.return_letter_dictionary(indexes= signal_dataset.features['id_measurement'].tolist())

# %%
# Segment the dataset
signal_dataset.segment_signals_by_dict('id_measurement', letter_dictionary, 'eurythmy_letter')

# %%
norm_letters_signal_dataset_path= r"..\data\interim\norm_letters_signal_dataset.pkl"

# %%
# Save the dataset
signal_dataset.save(norm_letters_signal_dataset_path)

# %% [markdown]
# ### Segmented in 1s (raw)

# %%
# Load raw dataset
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %%
# Segment Signals in 1sec segments
signal_dataset.segment_signals_by_duration(segment_duration= 1)

# %%
#Add eurythmy letter data to the features
df= ped.add_meas_letters(signal_dataset.features)

# %%
signal_dataset.features.shape
# Out:
# (148682, 8)

# %%
signal_dataset.features.iloc[15:20]
# Out:
#     id_measurement  id_performance    datetime  plant  generation  \
# 15               1               1  2023-04-29  salad           1
# 16               1               1  2023-04-29  salad           1
# 17               1               1  2023-04-29  salad           1
# 18               1               1  2023-04-29  salad           1
# 19               1               1  2023-04-29  salad           1
#
#     num_eurythmy  initial_second eurythmy_letter
# 15             1            15.0            None
# 16             1            16.0            None
# 17             1            17.0              A1
# 18             1            18.0              A1
# 19             1            19.0              A1

# %%
# Save the dataset
raw_1s_signal_dataset_path= r"..\data\raw\raw_1s_signal_dataset.pkl"
signal_dataset.save(raw_1s_signal_dataset_path)

# %% [markdown]
# ### Segmented in 1s (normalized)

# %%
# Load normalized dataset
signal_dataset= SignalDataset.load(norm_signal_dataset_path)

# %%
# Segment Signals in 1sec segments
signal_dataset.segment_signals_by_duration(segment_duration=1)

# %%
#Add eurythmy letter data to the features
df= ped.add_meas_letters(signal_dataset.features)

# %%
# Save the dataset
norm_1s_signal_dataset_path= r"..\data\interim\norm_1s_signal_dataset.pkl"
signal_dataset.save(norm_1s_signal_dataset_path)

# %% [markdown]
# ## Features Dataset

# %%
window_size= 2
hop_length= 2

feature_extractor= WavFeatureExtractor(sample_rate= 10000, lib_mfccs= True, pyau_mfccs= True, temporal= True,
                                       statistical= True, window_size= window_size, hop_length= hop_length)

# %% [markdown]
# ### Normalized letters

# %%
# Load dataset
signal_dataset= SignalDataset.load(norm_letters_signal_dataset_path)

# %%
# %%time

# Extract features and store in dataset
feat_dataset= FeaturesDataset.from_signal_dataset(signal_dataset, feature_extractor)
# Out:
# C:\Users\alvar\Documents\GitHub\Plant-Reactivity-Analysis\src\PlantReactivityAnalysis\features\wav_feature_extractor.py:297: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   feature_values.append(func(waveform_data))
# CPU times: total: 5h 2min 30s
# Wall time: 3h 46min 9s

# %%
feat_dataset.features.shape
# Out:
# (8878, 187)

# %%
feat_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter  lib_mfcc_1_avg  lib_mfcc_2_avg  \
# 0             1              A1      -29.677195       84.908073
# 1             1              G1     -100.697861       86.480331
# 2             1              D1       23.327625       89.250244
# 3             1              A2       14.845909       89.415977
# 4             1              G2      -51.320831       90.299484
#
#    lib_mfcc_3_avg  lib_mfcc_4_avg  lib_mfcc_5_avg  lib_mfcc_6_avg  \
# 0       23.882944       20.263571       13.948898       10.488656
# 1       30.171656       24.119730       17.713215       15.169153
# 2       26.221252       23.516384       16.444624       13.346057
# 3       26.323404       23.582859       16.572325       13.621408
# 4       27.181320       24.430511       17.382122       14.503346
#
#    lib_mfcc_7_avg  lib_mfcc_8_avg  lib_mfcc_9_avg  lib_mfcc_10_avg  \
# 0        8.994204        9.384411       10.199335         9.457244
# 1       12.242166       10.664472        9.575659         8.486410
# 2       10.357534        8.935259        7.906825         7.286381
# 3       10.702744        9.225565        8.070519         7.477998
# 4       11.689738       10.318517        9.089991         8.298073
#
#    lib_mfcc_11_avg  lib_mfcc_12_avg  lib_mfcc_13_avg  lib_mfcc_1_std  \
# 0         6.846077         5.528338         5.709393      102.744949
# 1         7.267684         6.799727         7.062698      124.047333
# 2         6.588382         6.108628         5.640996       60.338959
# 3         6.700114         6.021388         5.641294       48.275700
# 4         7.493353         6.917458         6.392589       90.932266
#
#    lib_mfcc_2_std  lib_mfcc_3_std  lib_mfcc_4_std  lib_mfcc_5_std  \
# 0        5.298808        5.641000        4.197596        5.010337
# 1        7.396371        5.954452        0.873340        0.997615
# 2        0.365579        0.368098        0.392962        0.265600
# 3        0.317327        0.272721        0.285732        0.262369
# 4        0.714640        0.705178        0.706185        0.706996
#
#    lib_mfcc_6_std  lib_mfcc_7_std  lib_mfcc_8_std  lib_mfcc_9_std  \
# 0        4.307392        3.860651        1.488685        1.654878
# 1        1.579578        1.280640        1.023308        1.342239
# 2        0.190609        0.318610        0.528917        0.752072
# 3        0.292171        0.322221        0.416858        0.315227
# 4        0.706821        0.704474        0.703918        0.704904
#
#    lib_mfcc_10_std  lib_mfcc_11_std  lib_mfcc_12_std  lib_mfcc_13_std  \
# 0         1.541794         1.190974         2.178400         1.267976
# 1         1.522926         1.815407         1.931284         1.195273
# 2         0.466588         0.234723         0.381310         0.696444
# 3         0.340292         0.284067         0.280039         0.272692
# 4         0.704429         0.701087         0.698257         0.699985
#
#    zcr_mean  energy_mean  energy_entropy_mean  spectral_centroid_mean  \
# 0   0.00004     0.082078             3.263784                0.031297
# 1   0.00007     0.056408             3.240514                0.033382
# 2   0.00011     0.198888             3.243688                0.047064
# 3   0.00008     0.125519             3.239510                0.043867
# 4   0.00003     0.130685             3.298378                0.022262
#
#    spectral_spread_mean  spectral_entropy_mean  spectral_flux_mean  \
# 0              0.078345               0.004577            0.017891
# 1              0.070873               0.008805            0.062599
# 2              0.130659               0.008520            0.029300
# 3              0.122151               0.007537            0.026346
# 4              0.057568               0.003529            0.019628
#
#    spectral_rolloff_mean  mfcc_1_mean  mfcc_2_mean  mfcc_3_mean  mfcc_4_mean  \
# 0                0.00020   -63.643573     1.191232     0.150986     0.205074
# 1                0.00054   -71.013852     0.934344     0.113942     0.159921
# 2                0.00060   -35.484054     2.098472     0.266080     0.372382
# 3                0.00048   -37.648317     2.105766     0.260733     0.371918
# 4                0.00024   -70.256599     0.957951     0.103165     0.163480
#
#    mfcc_5_mean  mfcc_6_mean  mfcc_7_mean  mfcc_8_mean  mfcc_9_mean  \
# 0     0.089766     0.098427     0.058357     0.057284     0.034696
# 1     0.065911     0.084083     0.049058     0.046657     0.033227
# 2     0.174787     0.186858     0.091070     0.086310     0.051997
# 3     0.162661     0.170489     0.094643     0.095728     0.054302
# 4     0.073303     0.082656     0.038803     0.040801     0.030035
#
#    mfcc_10_mean  mfcc_11_mean  mfcc_12_mean  mfcc_13_mean  chroma_1_mean  \
# 0      0.028017      0.017937      0.026331      0.014771       0.000041
# 1      0.045732      0.026167      0.023701      0.007208       0.000077
# 2      0.072076      0.043029      0.049743      0.044389       0.000060
# 3      0.054150      0.041564      0.049200      0.036355       0.000083
# 4      0.026299      0.017793      0.023184      0.021146       0.000043
#
#    chroma_2_mean  chroma_3_mean  chroma_4_mean  chroma_5_mean  chroma_6_mean  \
# 0       0.000007       0.001271       0.000041       0.196961       0.000023
# 1       0.000015       0.004001       0.000059       0.193966       0.000039
# 2       0.000014       0.002395       0.000070       0.193673       0.000059
# 3       0.000013       0.001865       0.000045       0.194239       0.000034
# 4       0.000004       0.001144       0.000021       0.197461       0.000014
#
#    chroma_7_mean  chroma_8_mean  chroma_9_mean  chroma_10_mean  \
# 0       0.005336       0.000003       0.000009        0.000033
# 1       0.009268       0.000009       0.000022        0.000128
# 2       0.011520       0.000008       0.000022        0.000059
# 3       0.011042       0.000007       0.000020        0.000071
# 4       0.004480       0.000004       0.000010        0.000028
#
#    chroma_11_mean  chroma_12_mean  chroma_std_mean  delta zcr_mean  \
# 0        0.000302        0.000011         0.054781             0.0
# 1        0.000421        0.000021         0.054876             0.0
# 2        0.000584        0.000016         0.055201             0.0
# 3        0.000367        0.000016         0.054814             0.0
# 4        0.000185        0.000005         0.055355             0.0
#
#    delta energy_mean  delta energy_entropy_mean  delta spectral_centroid_mean  \
# 0          -0.000099                  -0.001405                      0.000784
# 1          -0.004936                  -0.001000                      0.000610
# 2           0.001632                   0.000752                     -0.000325
# 3          -0.002200                   0.000959                     -0.000449
# 4          -0.003592                   0.000013                     -0.000097
#
#    delta spectral_spread_mean  delta spectral_entropy_mean  \
# 0                    0.001895                     0.000082
# 1                    0.001415                     0.000060
# 2                   -0.000393                    -0.000078
# 3                   -0.001340                    -0.000047
# 4                   -0.000501                    -0.000002
#
#    delta spectral_flux_mean  delta spectral_rolloff_mean  delta mfcc_1_mean  \
# 0              4.355507e-04                          0.0           0.696394
# 1              1.486803e-03                          0.0           0.338419
# 2             -1.271403e-04                          0.0           0.003235
# 3              1.904281e-04                          0.0          -0.676500
# 4              5.529431e-19                          0.0          -0.347323
#
#    delta mfcc_2_mean  delta mfcc_3_mean  delta mfcc_4_mean  delta mfcc_5_mean  \
# 0           0.023480           0.003132           0.004224           0.001443
# 1           0.012071           0.001420           0.002018           0.001082
# 2          -0.000322           0.000565           0.002180           0.001826
# 3          -0.023191          -0.004101          -0.006912          -0.003378
# 4          -0.011814          -0.001946          -0.002371          -0.000946
#
#    delta mfcc_6_mean  delta mfcc_7_mean  delta mfcc_8_mean  delta mfcc_9_mean  \
# 0           0.000917          -0.000189           0.001114           0.001192
# 1           0.001277           0.000951           0.001007           0.000592
# 2           0.001351           0.001931           0.000162          -0.002211
# 3          -0.001381          -0.000580          -0.000422           0.000586
# 4          -0.000162           0.000699           0.000042          -0.000993
#
#    delta mfcc_10_mean  delta mfcc_11_mean  delta mfcc_12_mean  \
# 0            0.000368           -0.000174            0.000826
# 1            0.000304            0.000067            0.000182
# 2           -0.000027           -0.001508            0.000718
# 3           -0.001661            0.000419           -0.000782
# 4           -0.000220            0.000465           -0.000335
#
#    delta mfcc_13_mean  delta chroma_1_mean  delta chroma_2_mean  \
# 0            0.000015         1.088596e-06         1.529988e-07
# 1            0.000228         6.820640e-07         4.103929e-08
# 2            0.000597        -4.753641e-07        -8.824976e-08
# 3           -0.000515        -1.544461e-07        -7.156323e-08
# 4           -0.000615        -1.497951e-08        -1.011559e-09
#
#    delta chroma_3_mean  delta chroma_4_mean  delta chroma_5_mean  \
# 0         1.818875e-05         1.980175e-07        -5.417746e-05
# 1         2.623151e-05         2.006327e-07        -3.584353e-05
# 2        -7.575922e-06        -3.715069e-07         3.047470e-05
# 3        -8.042627e-06        -5.083975e-07         3.792033e-05
# 4        -3.826463e-08        -1.778704e-08         5.250326e-07
#
#    delta chroma_6_mean  delta chroma_7_mean  delta chroma_8_mean  \
# 0         3.284261e-07             0.000103         7.679803e-08
# 1         3.023455e-07             0.000057         7.706319e-08
# 2        -2.796045e-07            -0.000062        -8.587731e-08
# 3        -1.362389e-07            -0.000080        -2.893988e-08
# 4        -3.506728e-09            -0.000001        -1.774368e-10
#
#    delta chroma_9_mean  delta chroma_10_mean  delta chroma_11_mean  \
# 0         2.701098e-07          8.086974e-07          2.930764e-06
# 1         9.362724e-08          1.905800e-07          6.562898e-07
# 2        -1.794641e-07         -1.956541e-07          3.896605e-08
# 3        -8.271910e-08         -3.878571e-07         -1.489236e-06
# 4        -6.034862e-09         -8.594750e-09         -7.866832e-09
#
#    delta chroma_12_mean  delta chroma_std_mean   zcr_std  energy_std  \
# 0          1.645357e-07          -1.743706e-05  0.000213    0.050824
# 1          8.735929e-08          -1.181173e-05  0.000270    0.061636
# 2         -1.587936e-07           9.659535e-06  0.000422    0.181552
# 3         -8.059749e-08           1.187632e-05  0.000238    0.114639
# 4         -1.292137e-09           1.755953e-07  0.000150    0.109744
#
#    energy_entropy_std  spectral_centroid_std  spectral_spread_std  \
# 0            0.127872               0.025220             0.058365
# 1            0.167907               0.034744             0.076751
# 2            0.176638               0.031505             0.050660
# 3            0.140752               0.029849             0.053218
# 4            0.056760               0.024160             0.059247
#
#    spectral_entropy_std  spectral_flux_std  spectral_rolloff_std  mfcc_1_std  \
# 0              0.013922           0.033209              0.001174   24.306081
# 1              0.020003           0.097263              0.001729   29.705222
# 2              0.022444           0.047820              0.002307   15.311098
# 3              0.015667           0.045692              0.001528   17.837538
# 4              0.011864           0.037923              0.001071   26.591407
#
#    mfcc_2_std  mfcc_3_std  mfcc_4_std  mfcc_5_std  mfcc_6_std  mfcc_7_std  \
# 0    0.847447    0.124643    0.165771    0.094005    0.108946    0.071663
# 1    1.000498    0.142186    0.192368    0.114031    0.104708    0.087990
# 2    0.543559    0.159506    0.164084    0.128049    0.110844    0.128876
# 3    0.614918    0.134647    0.137512    0.098725    0.108725    0.092424
# 4    0.892106    0.142480    0.174391    0.085396    0.094232    0.082790
#
#    mfcc_8_std  mfcc_9_std  mfcc_10_std  mfcc_11_std  mfcc_12_std  mfcc_13_std  \
# 0    0.090793    0.064725     0.071365     0.069437     0.067187     0.066383
# 1    0.099894    0.078608     0.102883     0.100889     0.080662     0.079898
# 2    0.140030    0.133731     0.134252     0.124542     0.107471     0.104524
# 3    0.104900    0.098382     0.117667     0.104820     0.095653     0.084537
# 4    0.064180    0.056771     0.058036     0.055482     0.052266     0.048362
#
#    chroma_1_std  chroma_2_std  chroma_3_std  chroma_4_std  chroma_5_std  \
# 0      0.000158      0.000029      0.005067      0.000163      0.009513
# 1      0.000214      0.000036      0.012218      0.000164      0.015067
# 2      0.000185      0.000049      0.007117      0.000240      0.018745
# 3      0.000251      0.000032      0.005000      0.000117      0.014145
# 4      0.000198      0.000014      0.004417      0.000072      0.011264
#
#    chroma_6_std  chroma_7_std  chroma_8_std  chroma_9_std  chroma_10_std  \
# 0      0.000089      0.014981      0.000008      0.000028       0.000084
# 1      0.000128      0.021524      0.000023      0.000054       0.000320
# 2      0.000203      0.034615      0.000025      0.000058       0.000154
# 3      0.000093      0.027255      0.000016      0.000050       0.000183
# 4      0.000052      0.021073      0.000013      0.000038       0.000092
#
#    chroma_11_std  chroma_12_std  chroma_std_std  delta zcr_std  \
# 0       0.001337       0.000045        0.000893       0.000306
# 1       0.001055       0.000057        0.001799       0.000396
# 2       0.001932       0.000050        0.003913       0.000554
# 3       0.000952       0.000037        0.002801       0.000282
# 4       0.000826       0.000016        0.002363       0.000216
#
#    delta energy_std  delta energy_entropy_std  delta spectral_centroid_std  \
# 0          0.044577                  0.151355                     0.022483
# 1          0.016894                  0.225994                     0.041033
# 2          0.078167                  0.190472                     0.029003
# 3          0.040608                  0.162164                     0.025767
# 4          0.031344                  0.058493                     0.022818
#
#    delta spectral_spread_std  delta spectral_entropy_std  \
# 0                   0.048718                    0.017942
# 1                   0.090611                    0.027381
# 2                   0.056592                    0.025669
# 3                   0.049208                    0.019629
# 4                   0.067099                    0.014640
#
#    delta spectral_flux_std  delta spectral_rolloff_std  delta mfcc_1_std  \
# 0                 0.038806                    0.001684         21.447741
# 1                 0.132122                    0.002485         33.715343
# 2                 0.058351                    0.002866         22.700861
# 3                 0.051782                    0.002207         23.160617
# 4                 0.038799                    0.001431         33.015017
#
#    delta mfcc_2_std  delta mfcc_3_std  delta mfcc_4_std  delta mfcc_5_std  \
# 0          0.769409          0.128675          0.159426          0.104661
# 1          1.146500          0.176029          0.220901          0.145257
# 2          0.806247          0.234575          0.247159          0.186039
# 3          0.807444          0.182331          0.182377          0.143348
# 4          1.120694          0.193414          0.221580          0.108853
#
#    delta mfcc_6_std  delta mfcc_7_std  delta mfcc_8_std  delta mfcc_9_std  \
# 0          0.136940          0.094367          0.117136          0.086324
# 1          0.134314          0.125225          0.131326          0.110507
# 2          0.161244          0.185310          0.193026          0.187899
# 3          0.168167          0.127159          0.146827          0.142618
# 4          0.117628          0.111035          0.085365          0.079396
#
#    delta mfcc_10_std  delta mfcc_11_std  delta mfcc_12_std  delta mfcc_13_std  \
# 0           0.096386           0.097812           0.091364           0.095250
# 1           0.147746           0.141739           0.110147           0.111929
# 2           0.191078           0.185796           0.155922           0.148978
# 3           0.155136           0.154500           0.129711           0.115196
# 4           0.080952           0.073726           0.074666           0.068073
#
#    delta chroma_1_std  delta chroma_2_std  delta chroma_3_std  \
# 0            0.000210            0.000039            0.006984
# 1            0.000306            0.000050            0.016980
# 2            0.000227            0.000064            0.008686
# 3            0.000350            0.000045            0.006960
# 4            0.000271            0.000016            0.005832
#
#    delta chroma_4_std  delta chroma_5_std  delta chroma_6_std  \
# 0            0.000214            0.012332            0.000120
# 1            0.000224            0.021255            0.000183
# 2            0.000303            0.021443            0.000260
# 3            0.000159            0.018861            0.000126
# 4            0.000088            0.015451            0.000068
#
#    delta chroma_7_std  delta chroma_8_std  delta chroma_9_std  \
# 0            0.018749            0.000010            0.000034
# 1            0.030644            0.000032            0.000077
# 2            0.039803            0.000033            0.000069
# 3            0.036385            0.000020            0.000067
# 4            0.029219            0.000016            0.000048
#
#    delta chroma_10_std  delta chroma_11_std  delta chroma_12_std  \
# 0             0.000102             0.001867             0.000059
# 1             0.000441             0.001462             0.000081
# 2             0.000187             0.002277             0.000061
# 3             0.000239             0.001263             0.000046
# 4             0.000115             0.001094             0.000020
#
#    delta chroma_std_std  zero_crossing_rate  root_mean_square_energy  \
# 0              0.001023            0.000017                 1.443897
# 1              0.002617            0.000006                 0.732309
# 2              0.005689            0.000033                 1.401224
# 3              0.003709            0.000067                 1.631849
# 4              0.003393            0.000017                 0.771450
#
#    slope_sign_changes_ratio  duration_seconds  flatness_ratio_10000  \
# 0                  0.018133               9.0              0.352622
# 1                  0.002644               9.0              0.328122
# 2                  0.010444               9.0              0.000000
# 3                  0.012356               9.0              0.000000
# 4                  0.003511               9.0              0.111556
#
#    flatness_ratio_5000  flatness_ratio_1000  flatness_ratio_500  \
# 0             0.352622             0.536244            0.616367
# 1             0.328122             0.688267            0.812756
# 2             0.000000             0.039000            0.279922
# 3             0.000000             0.053656            0.217267
# 4             0.334178             0.604156            0.740889
#
#    flatness_ratio_100  hjorth_mobility  hjorth_complexity      mean  variance  \
# 0            0.774433         0.000017       80464.145670 -0.069488  2.080011
# 1            0.982800         0.000021       54194.021625  0.579218  0.200783
# 2            0.871789         0.000020       59588.992615 -1.019622  0.923799
# 3            0.848300         0.000015       87704.209952 -0.912563  1.830160
# 4            0.978600         0.000022       52998.819272  0.371457  0.457155
#
#    standard_deviation  interquartile_range  skewness  kurtosis       dfa
# 0            1.442224             1.082166 -1.651490  1.428384  1.652581
# 1            0.448089             0.144289 -2.380866  4.743071  1.640983
# 2            0.961145             1.515033 -0.104159 -0.900896  1.679972
# 3            1.352834             1.442888 -1.178505  0.668149  1.672634
# 4            0.676132             0.577155 -1.348706  0.188683  1.734061

# %%
# Save the dataset
feat_norm_letters_dataset_path= r"..\data\processed\feat_norm_letters_" + str(window_size) + "_" + str(hop_length) + "_dataset.pkl"
feat_dataset.save(feat_norm_letters_dataset_path)

# %% [markdown]
# ### Letters

# %%
# Load dataset
signal_dataset= SignalDataset.load(raw_letters_signal_dataset_path)

# %%
# %%time

# Extract features and store in dataset
feat_dataset= FeaturesDataset.from_signal_dataset(signal_dataset, feature_extractor)
# Out:
# C:\Users\alvar\Documents\GitHub\Plant-Reactivity-Analysis\src\PlantReactivityAnalysis\features\wav_feature_extractor.py:297: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   feature_values.append(func(waveform_data))
# CPU times: total: 5h 8min 1s
# Wall time: 4h 55s

# %%
# Save the dataset
feat_raw_letters_dataset_path= r"..\data\processed\feat_raw_letters_" + str(window_size) + "_" + str(hop_length) + "_dataset.pkl"
feat_dataset.save(feat_raw_letters_dataset_path)
