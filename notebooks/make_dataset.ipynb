# %% [markdown]
# # Make Dataset

# %% [markdown]
# ## Imports

# %%
from PlantReactivityAnalysis.data.wav_data_reader import WavDataReader
from PlantReactivityAnalysis.data.signal_dataset import SignalDataset
from PlantReactivityAnalysis.features.wav_feature_extractor import WavFeatureExtractor
from PlantReactivityAnalysis.features.features_dataset import FeaturesDataset
import PlantReactivityAnalysis.data.preparation_eurythmy_data as ped

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Reader

# %%
wav_folder= r"..\data\raw\wav_files"
#wav_folder= r"..\data\interim\testing"

# %%
# Initialize the reader with the folder of wavs
reader= WavDataReader(folder= wav_folder, sample_rate= 10000)

# Get the signals and the keys from the reader
signals, ids= reader.get_ordered_signals_and_keys()

# Get the measurement labels from the keys of the files
meas_df= ped.return_meas_labels_by_keys(ids)
# Out:
# Total WAV files read: 625

# %%
meas_df.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  num_eurythmy
# 0               1               1  2023-04-29  salad           1             1
# 1               2               1  2023-04-29  salad           1             1
# 2               3               1  2023-04-29  salad           1             1
# 3               4               1  2023-04-29  salad           2             0
# 4               5               1  2023-04-29  salad           2             0

# %% [markdown]
# ## Signal Dataset

# %% [markdown]
# ### Raw

# %%
# Initialize SignalDataset with the signals and features/labels
signal_dataset= SignalDataset(signals= signals, features= meas_df)

# %%
signal_dataset.features.shape
# Out:
# (625, 6)

# %%
signal_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  num_eurythmy
# 0               1               1  2023-04-29  salad           1             1
# 1               2               1  2023-04-29  salad           1             1
# 2               3               1  2023-04-29  salad           1             1
# 3               4               1  2023-04-29  salad           2             0
# 4               5               1  2023-04-29  salad           2             0

# %%
# Save and Load the dataset
raw_signal_dataset_path= r"..\data\raw\raw_signal_dataset.pkl"

# %%
signal_dataset.save(raw_signal_dataset_path)
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %% [markdown]
# ### Normalized

# %%
# Standardize Signals using Zscore
signal_dataset.standardize_signals("zscore")

# %%
signal_dataset.features.shape
# Out:
# (625, 6)

# %%
# Save the dataset
norm_signal_dataset_path= r"..\data\interim\norm_signal_dataset.pkl"
signal_dataset.save(norm_signal_dataset_path)

# %% [markdown]
# ### Segmented by Letters (raw)

# %%
# Load raw dataset
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %%
# Get Letter segments from raw data
letter_dictionary= ped.return_letter_dictionary(indexes= signal_dataset.features['id_measurement'].tolist())

# %%
# Segment the dataset
signal_dataset.segment_signals_by_dict('id_measurement', letter_dictionary, 'eurythmy_letter')

# %%
signal_dataset.features.shape #8390, 7
# Out:
# (8878, 7)

# %%
signal_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter
# 0             1              A1
# 1             1              G1
# 2             1              D1
# 3             1              A2
# 4             1              G2

# %%
raw_letters_signal_dataset_path= r"..\data\raw\raw_letters_signal_dataset.pkl"

# %%
# Save the dataset
signal_dataset.save(raw_letters_signal_dataset_path)

# %% [markdown]
# ### Segmented by Letters (normalized)

# %%
# Load normalized dataset
signal_dataset= SignalDataset.load(norm_signal_dataset_path)

# %%
# Get Letter segments from raw data
letter_dictionary= ped.return_letter_dictionary(indexes= signal_dataset.features['id_measurement'].tolist())

# %%
# Segment the dataset
signal_dataset.segment_signals_by_dict('id_measurement', letter_dictionary, 'eurythmy_letter')

# %%
norm_letters_signal_dataset_path= r"..\data\interim\norm_letters_signal_dataset.pkl"

# %%
# Save the dataset
signal_dataset.save(norm_letters_signal_dataset_path)

# %% [markdown]
# ### Segmented in 1s (raw)

# %%
# Load raw dataset
signal_dataset= SignalDataset.load(raw_signal_dataset_path)

# %%
# Segment Signals in 1sec segments
signal_dataset.segment_signals_by_duration(segment_duration= 1)

# %%
#Add eurythmy letter data to the features
df= ped.add_meas_letters(signal_dataset.features)

# %%
signal_dataset.features.shape
# Out:
# (148682, 8)

# %%
signal_dataset.features.iloc[15:20]
# Out:
#     id_measurement  id_performance    datetime  plant  generation  \
# 15               1               1  2023-04-29  salad           1
# 16               1               1  2023-04-29  salad           1
# 17               1               1  2023-04-29  salad           1
# 18               1               1  2023-04-29  salad           1
# 19               1               1  2023-04-29  salad           1
#
#     num_eurythmy  initial_second eurythmy_letter
# 15             1            15.0            None
# 16             1            16.0            None
# 17             1            17.0              A1
# 18             1            18.0              A1
# 19             1            19.0              A1

# %%
# Save the dataset
raw_1s_signal_dataset_path= r"..\data\raw\raw_1s_signal_dataset.pkl"
signal_dataset.save(raw_1s_signal_dataset_path)

# %% [markdown]
# ### Segmented in 1s (normalized)

# %%
# Load normalized dataset
signal_dataset= SignalDataset.load(norm_signal_dataset_path)

# %%
# Segment Signals in 1sec segments
signal_dataset.segment_signals_by_duration(segment_duration=1)

# %%
#Add eurythmy letter data to the features
df= ped.add_meas_letters(signal_dataset.features)

# %%
# Save the dataset
norm_1s_signal_dataset_path= r"..\data\interim\norm_1s_signal_dataset.pkl"
signal_dataset.save(norm_1s_signal_dataset_path)

# %% [markdown]
# ## Features Dataset

# %%
window_size= 1
hop_length= 1

feature_extractor= WavFeatureExtractor(sample_rate= 10000, lib_mfccs= True, pyau_mfccs= True, temporal= True,
                                       statistical= True, window_size= window_size, hop_length= hop_length)

# %% [markdown]
# ### Normalized letters

# %%
# Load dataset
signal_dataset= SignalDataset.load(norm_letters_signal_dataset_path)

# %%
# %%time

# Extract features and store in dataset
feat_dataset= FeaturesDataset.from_signal_dataset(signal_dataset, feature_extractor)
# Out:
# C:\Users\alvar\Documents\GitHub\Plant-Reactivity-Analysis\src\PlantReactivityAnalysis\features\wav_feature_extractor.py:297: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   feature_values.append(func(waveform_data))
# CPU times: total: 4h 57min 5s
# Wall time: 4h 1min 24s

# %%
feat_dataset.features.shape
# Out:
# (8878, 187)

# %%
feat_dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter  lib_mfcc_1_avg  lib_mfcc_2_avg  \
# 0             1              A1      -97.838631       69.273560
# 1             1              G1     -151.758621       76.297348
# 2             1              D1      -39.021881       89.484283
# 3             1              A2      -35.181309       88.256424
# 4             1              G2     -127.330101       88.080475
#
#    lib_mfcc_3_avg  lib_mfcc_4_avg  lib_mfcc_5_avg  lib_mfcc_6_avg  \
# 0       23.362997       19.670675       13.726768       11.218821
# 1       25.773884       23.195232       17.153683       14.401384
# 2       26.571812       23.835693       16.747375       13.777249
# 3       25.609610       22.896559       15.855588       12.917089
# 4       28.749460       24.442780       17.571262       14.899020
#
#    lib_mfcc_7_avg  lib_mfcc_8_avg  lib_mfcc_9_avg  lib_mfcc_10_avg  \
# 0        9.208938        8.885289        8.858075         8.523602
# 1       11.833508       10.480188        9.294729         8.389806
# 2       10.816953        9.473647        8.450934         7.695979
# 3       10.019514        8.652267        7.855108         7.729014
# 4       12.060678       10.527637        9.346112         8.616164
#
#    lib_mfcc_11_avg  lib_mfcc_12_avg  lib_mfcc_13_avg  lib_mfcc_1_std  \
# 0         7.353079         6.539922         6.364826      118.226295
# 1         7.522802         7.051421         6.996970      133.723511
# 2         6.742785         6.240778         5.757567       74.634789
# 3         7.010394         5.972252         5.486945       61.873417
# 4         7.778655         7.169141         6.660098      109.931023
#
#    lib_mfcc_2_std  lib_mfcc_3_std  lib_mfcc_4_std  lib_mfcc_5_std  \
# 0       26.501040        9.378350        6.639277        5.881349
# 1       27.914768        5.736088        4.853868        3.402934
# 2        0.521752        0.517014        0.516875        0.381142
# 3        2.751151        2.160524        2.043172        1.934997
# 4        6.278783        4.672277        0.902494        0.954311
#
#    lib_mfcc_6_std  lib_mfcc_7_std  lib_mfcc_8_std  lib_mfcc_9_std  \
# 0        5.224013        4.339543        2.838975        1.978278
# 1        2.528081        1.871545        1.410442        1.231589
# 2        0.408188        0.682959        0.599139        0.880994
# 3        1.894169        1.974840        1.669991        0.551645
# 4        1.282215        1.246059        1.011890        1.154138
#
#    lib_mfcc_10_std  lib_mfcc_11_std  lib_mfcc_12_std  lib_mfcc_13_std  \
# 0         1.259007         1.849545         2.406303         1.947991
# 1         1.254152         1.676308         1.889821         1.557738
# 2         0.617856         0.334806         0.482080         0.731387
# 3         1.013694         1.244305         0.423966         0.286011
# 4         1.217876         1.117111         1.066348         1.162418
#
#    zcr_mean  energy_mean  energy_entropy_mean  spectral_centroid_mean  \
# 0  0.000033     0.088971             3.264958                0.030536
# 1  0.000056     0.061664             3.262174                0.029286
# 2  0.000089     0.186490             3.247740                0.046170
# 3  0.000089     0.123615             3.230978                0.046237
# 4  0.000033     0.139059             3.295916                0.023946
#
#    spectral_spread_mean  spectral_entropy_mean  spectral_flux_mean  \
# 0              0.076987               0.004579            0.017933
# 1              0.063262               0.006898            0.052122
# 2              0.128797               0.007804            0.029033
# 3              0.125896               0.008328            0.028481
# 4              0.062572               0.003911            0.021432
#
#    spectral_rolloff_mean  mfcc_1_mean  mfcc_2_mean  mfcc_3_mean  mfcc_4_mean  \
# 0               0.000200   -63.783953     1.185665     0.148074     0.201866
# 1               0.000422   -73.209831     0.857017     0.103996     0.149589
# 2               0.000511   -36.167952     2.079668     0.264204     0.369089
# 3               0.000533   -37.175691     2.120212     0.260140     0.373992
# 4               0.000267   -67.812965     1.038983     0.111559     0.177122
#
#    mfcc_5_mean  mfcc_6_mean  mfcc_7_mean  mfcc_8_mean  mfcc_9_mean  \
# 0     0.089235     0.099855     0.060547     0.056997     0.035531
# 1     0.063560     0.075580     0.042261     0.046169     0.031771
# 2     0.171541     0.185854     0.090748     0.085453     0.048311
# 3     0.163257     0.170304     0.093428     0.096943     0.058916
# 4     0.079309     0.089514     0.041811     0.044066     0.032745
#
#    mfcc_10_mean  mfcc_11_mean  mfcc_12_mean  mfcc_13_mean  chroma_1_mean  \
# 0      0.029857      0.016570      0.024122      0.015072       0.000042
# 1      0.038990      0.027234      0.018053      0.005316       0.000068
# 2      0.073510      0.044454      0.048333      0.041639       0.000054
# 3      0.057099      0.043966      0.050175      0.034436       0.000091
# 4      0.028580      0.019434      0.025346      0.023216       0.000048
#
#    chroma_2_mean  chroma_3_mean  chroma_4_mean  chroma_5_mean  chroma_6_mean  \
# 0       0.000008       0.001330       0.000040       0.196965       0.000023
# 1       0.000011       0.003175       0.000043       0.195497       0.000035
# 2       0.000012       0.001944       0.000064       0.194609       0.000052
# 3       0.000014       0.002065       0.000050       0.193622       0.000038
# 4       0.000005       0.001268       0.000023       0.197185       0.000015
#
#    chroma_7_mean  chroma_8_mean  chroma_9_mean  chroma_10_mean  \
# 0       0.005240       0.000003       0.000009        0.000032
# 1       0.006649       0.000007       0.000016        0.000093
# 2       0.009793       0.000007       0.000020        0.000057
# 3       0.012225       0.000007       0.000022        0.000078
# 4       0.004966       0.000004       0.000011        0.000031
#
#    chroma_11_mean  chroma_12_mean  chroma_std_mean  delta zcr_mean  \
# 0        0.000315        0.000011         0.054824             0.0
# 1        0.000334        0.000017         0.054960             0.0
# 2        0.000537        0.000014         0.055029             0.0
# 3        0.000406        0.000017         0.054771             0.0
# 4        0.000205        0.000005         0.055365             0.0
#
#    delta energy_mean  delta energy_entropy_mean  delta spectral_centroid_mean  \
# 0          -0.000055                  -0.000780                      0.000436
# 1          -0.005452                  -0.000555                      0.000314
# 2           0.000624                   0.000064                     -0.000070
# 3           0.000132                   0.001057                     -0.000433
# 4          -0.003991                   0.000015                     -0.000108
#
#    delta spectral_spread_mean  delta spectral_entropy_mean  \
# 0                    0.001053                     0.000045
# 1                    0.000595                     0.000033
# 2                   -0.000100                    -0.000007
# 3                   -0.001050                    -0.000052
# 4                   -0.000557                    -0.000002
#
#    delta spectral_flux_mean  delta spectral_rolloff_mean  delta mfcc_1_mean  \
# 0              2.419726e-04                          0.0           0.386885
# 1              8.260015e-04                          0.0           0.000785
# 2              4.527081e-05                          0.0          -0.000118
# 3              1.110854e-04                          0.0          -0.378112
# 4              4.878910e-19                          0.0          -0.385915
#
#    delta mfcc_2_mean  delta mfcc_3_mean  delta mfcc_4_mean  delta mfcc_5_mean  \
# 0           0.013045           0.001740           0.002347           0.000802
# 1           0.000639          -0.000016          -0.000082           0.000077
# 2          -0.000197          -0.000254           0.000223           0.001039
# 3          -0.012837          -0.001571          -0.002246          -0.000986
# 4          -0.013126          -0.002162          -0.002634          -0.001051
#
#    delta mfcc_6_mean  delta mfcc_7_mean  delta mfcc_8_mean  delta mfcc_9_mean  \
# 0           0.000510          -0.000105           0.000619           0.000662
# 1           0.000195           0.000340           0.000401           0.000210
# 2           0.001770           0.000972          -0.000479          -0.000549
# 3          -0.001091          -0.000672          -0.000653          -0.000334
# 4          -0.000180           0.000776           0.000047          -0.001104
#
#    delta mfcc_10_mean  delta mfcc_11_mean  delta mfcc_12_mean  \
# 0            0.000205           -0.000097            0.000459
# 1           -0.000048           -0.000138           -0.000108
# 2           -0.000097           -0.000681            0.000187
# 3           -0.000300           -0.000210           -0.000337
# 4           -0.000244            0.000517           -0.000372
#
#    delta mfcc_13_mean  delta chroma_1_mean  delta chroma_2_mean  \
# 0            0.000008         6.047754e-07         8.499934e-08
# 1            0.000010         3.777188e-07         2.274788e-08
# 2            0.000720        -1.114784e-07        -4.332987e-09
# 3           -0.000306        -1.633791e-07        -7.908155e-08
# 4           -0.000684        -1.664390e-08        -1.123955e-09
#
#    delta chroma_3_mean  delta chroma_4_mean  delta chroma_5_mean  \
# 0         1.010486e-05         1.100097e-07        -3.009859e-05
# 1         1.453678e-05         1.103207e-07        -1.986442e-05
# 2        -1.182349e-06        -9.670379e-08         2.380916e-06
# 3        -8.845388e-06        -5.612370e-07         4.182813e-05
# 4        -4.251626e-08        -1.976337e-08         5.833696e-07
#
#    delta chroma_6_mean  delta chroma_7_mean  delta chroma_8_mean  \
# 0         1.824589e-07             0.000057         4.266557e-08
# 1         1.676313e-07             0.000032         4.274459e-08
# 2        -4.477795e-08            -0.000004        -3.393578e-09
# 3        -1.469776e-07            -0.000088        -3.202806e-08
# 4        -3.896364e-09            -0.000001        -1.971520e-10
#
#    delta chroma_9_mean  delta chroma_10_mean  delta chroma_11_mean  \
# 0         1.500610e-07          4.492763e-07          1.628202e-06
# 1         5.185454e-08          1.055283e-07          3.544756e-07
# 2        -4.870197e-08         -3.643277e-08          3.406729e-07
# 3        -9.100147e-08         -4.245099e-07         -1.640388e-06
# 4        -6.705402e-09         -9.549722e-09         -8.740924e-09
#
#    delta chroma_12_mean  delta chroma_std_mean   zcr_std  energy_std  \
# 0          9.140872e-08          -9.687256e-06  0.000146    0.053164
# 1          4.820520e-08          -6.545901e-06  0.000212    0.031881
# 2         -2.457836e-08           7.894906e-07  0.000319    0.127388
# 3         -8.894644e-08           1.309342e-05  0.000217    0.053695
# 4         -1.435708e-09           1.951059e-07  0.000146    0.080914
#
#    energy_entropy_std  spectral_centroid_std  spectral_spread_std  \
# 0            0.097423               0.019238             0.044314
# 1            0.124692               0.030180             0.066916
# 2            0.150180               0.029138             0.049793
# 3            0.119859               0.024520             0.043831
# 4            0.056192               0.023802             0.058919
#
#    spectral_entropy_std  spectral_flux_std  spectral_rolloff_std  mfcc_1_std  \
# 0              0.010767           0.027899              0.000872   18.334360
# 1              0.016484           0.074710              0.001473   24.990641
# 2              0.017960           0.041468              0.001750   15.128978
# 3              0.013701           0.039527              0.001391   14.900734
# 4              0.011343           0.035032              0.001019   24.906335
#
#    mfcc_2_std  mfcc_3_std  mfcc_4_std  mfcc_5_std  mfcc_6_std  mfcc_7_std  \
# 0    0.644265    0.104472    0.136991    0.080117    0.093298    0.064427
# 1    0.839400    0.125326    0.160711    0.095185    0.092746    0.073359
# 2    0.534141    0.161547    0.169583    0.127013    0.109570    0.129995
# 3    0.519694    0.129107    0.128526    0.096237    0.102634    0.086337
# 4    0.838537    0.136411    0.163105    0.082422    0.091643    0.079026
#
#    mfcc_8_std  mfcc_9_std  mfcc_10_std  mfcc_11_std  mfcc_12_std  mfcc_13_std  \
# 0    0.081773    0.057405     0.060885     0.061697     0.058945     0.059256
# 1    0.084875    0.074347     0.087786     0.083423     0.065120     0.069007
# 2    0.143724    0.133723     0.135032     0.125536     0.109622     0.101762
# 3    0.102663    0.097634     0.107512     0.096927     0.090498     0.080579
# 4    0.063215    0.056482     0.059726     0.056717     0.054456     0.051159
#
#    chroma_1_std  chroma_2_std  chroma_3_std  chroma_4_std  chroma_5_std  \
# 0      0.000122      0.000022      0.003948      0.000124      0.007312
# 1      0.000204      0.000027      0.009846      0.000117      0.011784
# 2      0.000142      0.000037      0.005095      0.000186      0.014123
# 3      0.000206      0.000027      0.004182      0.000097      0.012068
# 4      0.000173      0.000014      0.004208      0.000071      0.009819
#
#    chroma_6_std  chroma_7_std  chroma_8_std  chroma_9_std  chroma_10_std  \
# 0      0.000069      0.011435      0.000006      0.000022       0.000065
# 1      0.000110      0.016113      0.000018      0.000040       0.000237
# 2      0.000153      0.026135      0.000020      0.000049       0.000132
# 3      0.000081      0.023332      0.000014      0.000042       0.000145
# 4      0.000051      0.017751      0.000013      0.000034       0.000090
#
#    chroma_11_std  chroma_12_std  chroma_std_std  delta zcr_std  \
# 0       0.001030       0.000035        0.000670       0.000211
# 1       0.000868       0.000048        0.001538       0.000311
# 2       0.001497       0.000037        0.002956       0.000433
# 3       0.000805       0.000031        0.002413       0.000270
# 4       0.000696       0.000015        0.002082       0.000211
#
#    delta energy_std  delta energy_entropy_std  delta spectral_centroid_std  \
# 0          0.047956                  0.120787                     0.020865
# 1          0.013422                  0.167148                     0.035288
# 2          0.065063                  0.166706                     0.028230
# 3          0.032662                  0.144298                     0.025188
# 4          0.032030                  0.058244                     0.023484
#
#    delta spectral_spread_std  delta spectral_entropy_std  \
# 0                   0.048218                    0.014285
# 1                   0.080392                    0.022627
# 2                   0.057625                    0.021072
# 3                   0.048007                    0.017697
# 4                   0.067952                    0.013950
#
#    delta spectral_flux_std  delta spectral_rolloff_std  delta mfcc_1_std  \
# 0                 0.032865                    0.001265         20.755186
# 1                 0.102325                    0.002125         30.416615
# 2                 0.052685                    0.002237         22.822836
# 3                 0.048755                    0.002061         20.034402
# 4                 0.037669                    0.001356         32.630013
#
#    delta mfcc_2_std  delta mfcc_3_std  delta mfcc_4_std  delta mfcc_5_std  \
# 0          0.740586          0.126518          0.159216          0.100205
# 1          1.031922          0.161810          0.196821          0.123788
# 2          0.810829          0.242546          0.256488          0.186482
# 3          0.703564          0.173900          0.168674          0.137296
# 4          1.114373          0.195600          0.223128          0.112655
#
#    delta mfcc_6_std  delta mfcc_7_std  delta mfcc_8_std  delta mfcc_9_std  \
# 0          0.126061          0.089695          0.109876          0.078372
# 1          0.122129          0.107537          0.116526          0.105646
# 2          0.159857          0.188615          0.200064          0.186581
# 3          0.159249          0.122341          0.145849          0.138655
# 4          0.122641          0.111310          0.087495          0.079817
#
#    delta mfcc_10_std  delta mfcc_11_std  delta mfcc_12_std  delta mfcc_13_std  \
# 0           0.085441           0.090546           0.083349           0.086447
# 1           0.126138           0.119678           0.091077           0.098802
# 2           0.192952           0.187032           0.157770           0.144459
# 3           0.143030           0.142541           0.127976           0.112510
# 4           0.084577           0.076566           0.079936           0.073167
#
#    delta chroma_1_std  delta chroma_2_std  delta chroma_3_std  \
# 0            0.000166            0.000031            0.005522
# 1            0.000292            0.000037            0.013848
# 2            0.000175            0.000049            0.006217
# 3            0.000287            0.000039            0.005955
# 4            0.000237            0.000016            0.005400
#
#    delta chroma_4_std  delta chroma_5_std  delta chroma_6_std  \
# 0            0.000166            0.009742            0.000095
# 1            0.000162            0.016631            0.000158
# 2            0.000240            0.016613            0.000200
# 3            0.000135            0.016532            0.000111
# 4            0.000087            0.013283            0.000068
#
#    delta chroma_7_std  delta chroma_8_std  delta chroma_9_std  \
# 0            0.014809            0.000008            0.000028
# 1            0.022809            0.000026            0.000057
# 2            0.030997            0.000026            0.000060
# 3            0.031939            0.000018            0.000058
# 4            0.024470            0.000016            0.000043
#
#    delta chroma_10_std  delta chroma_11_std  delta chroma_12_std  \
# 0             0.000082             0.001463             0.000047
# 1             0.000326             0.001212             0.000068
# 2             0.000163             0.001828             0.000045
# 3             0.000195             0.001106             0.000040
# 4             0.000111             0.000916             0.000018
#
#    delta chroma_std_std  zero_crossing_rate  root_mean_square_energy  \
# 0              0.000820            0.000017                 1.443897
# 1              0.002225            0.000006                 0.732309
# 2              0.004270            0.000033                 1.401224
# 3              0.003139            0.000067                 1.631849
# 4              0.002950            0.000017                 0.771450
#
#    slope_sign_changes_ratio  duration_seconds  flatness_ratio_10000  \
# 0                  0.018133               9.0              0.352622
# 1                  0.002644               9.0              0.328122
# 2                  0.010444               9.0              0.000000
# 3                  0.012356               9.0              0.000000
# 4                  0.003511               9.0              0.111556
#
#    flatness_ratio_5000  flatness_ratio_1000  flatness_ratio_500  \
# 0             0.352622             0.536244            0.616367
# 1             0.328122             0.688267            0.812756
# 2             0.000000             0.039000            0.279922
# 3             0.000000             0.053656            0.217267
# 4             0.334178             0.604156            0.740889
#
#    flatness_ratio_100  hjorth_mobility  hjorth_complexity      mean  variance  \
# 0            0.774433         0.000017       80464.145670 -0.069488  2.080011
# 1            0.982800         0.000021       54194.021625  0.579218  0.200783
# 2            0.871789         0.000020       59588.992615 -1.019622  0.923799
# 3            0.848300         0.000015       87704.209952 -0.912563  1.830160
# 4            0.978600         0.000022       52998.819272  0.371457  0.457155
#
#    standard_deviation  interquartile_range  skewness  kurtosis       dfa
# 0            1.442224             1.082166 -1.651490  1.428384  1.652581
# 1            0.448089             0.144289 -2.380866  4.743071  1.640983
# 2            0.961145             1.515033 -0.104159 -0.900896  1.679972
# 3            1.352834             1.442888 -1.178505  0.668149  1.672634
# 4            0.676132             0.577155 -1.348706  0.188683  1.734061

# %%
# Save the dataset
feat_norm_letters_dataset_path= r"..\data\processed\feat_norm_letters_" + str(window_size) + "_" + str(hop_length) + "_dataset.pkl"
feat_dataset.save(feat_norm_letters_dataset_path)

# %% [markdown]
# ### Letters

# %%
# Load dataset
signal_dataset= SignalDataset.load(raw_letters_signal_dataset_path)

# %%
# %%time

# Extract features and store in dataset
feat_dataset= FeaturesDataset.from_signal_dataset(signal_dataset, feature_extractor)
# Out:
# C:\Users\alvar\Documents\GitHub\Plant-Reactivity-Analysis\src\PlantReactivityAnalysis\features\wav_feature_extractor.py:297: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   feature_values.append(func(waveform_data))
# CPU times: total: 5h 15min 25s
# Wall time: 9h 31min 10s

# %%
# Save the dataset
feat_raw_letters_dataset_path= r"..\data\processed\feat_raw_letters_" + str(window_size) + "_" + str(hop_length) + "_dataset.pkl"
feat_dataset.save(feat_raw_letters_dataset_path)
