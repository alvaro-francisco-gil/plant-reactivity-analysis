# %% [markdown]
# # Experiment Eurythmy Letter

# %%
from PlantReactivityAnalysis.features.features_dataset import FeaturesDataset
from PlantReactivityAnalysis.models.experiment import Experiment
import PlantReactivityAnalysis.models.help_experiment as he
import PlantReactivityAnalysis.models.parameters as param
from PlantReactivityAnalysis.config import PROCESSED_DATA_DIR

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
norm_letters_signal_dataset_path = r"../data/processed/feat_norm_letters_1_1_dataset.pkl"

# %% [markdown]
# # Preparation

# %%
datasets= he.collect_all_rqs_data(corr_threshold=0.8, pca_dim=0)
# Out:
# PROCESSING DATASET  1
# Removing columns with NaN values: ['kurtosis', 'skewness']
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3395, Percentage = 50.58%
# Class 0: Count = 3317, Percentage = 49.42%
# -Test distribution-
# Counts and Percentages:
# Class 1: Count = 846, Percentage = 50.42%
# Class 0: Count = 832, Percentage = 49.58%
# Reduced variable features from initial count to 44.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 1002, Percentage = 33.57%
# Class 0: Count = 998, Percentage = 33.43%
# Class 2: Count = 985, Percentage = 33.00%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 257, Percentage = 34.40%
# Class 2: Count = 249, Percentage = 33.33%
# Class 1: Count = 241, Percentage = 32.26%
# Reduced variable features from initial count to 50.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2561, Percentage = 38.16%
# Class 2: Count = 2152, Percentage = 32.06%
# Class 1: Count = 1999, Percentage = 29.78%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 631, Percentage = 37.60%
# Class 1: Count = 541, Percentage = 32.24%
# Class 2: Count = 506, Percentage = 30.15%
# Reduced variable features from initial count to 45.
# Reduced features based on correlation threshold of 0.8
#
# PROCESSING DATASET  2
# Removing columns with NaN values: ['kurtosis', 'skewness']
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3395, Percentage = 50.58%
# Class 0: Count = 3317, Percentage = 49.42%
# -Test distribution-
# Counts and Percentages:
# Class 1: Count = 846, Percentage = 50.42%
# Class 0: Count = 832, Percentage = 49.58%
# Reduced variable features from initial count to 44.
# Reduced features based on correlation threshold of 0.8
#                           1          0        p_value
# mfcc_1_std        15.452480  22.122096  1.491333e-198
# mfcc_2_std         0.526064   0.744023  1.968266e-197
# mfcc_2_mean        1.884291   1.506518  4.069004e-190
# mfcc_4_mean        0.333911   0.268655  1.863441e-183
# delta mfcc_1_std  20.816261  29.577311  1.049811e-181
# mfcc_3_mean        0.235375   0.189378  2.669175e-180
# mfcc_6_mean        0.159752   0.128396  3.027117e-180
# delta mfcc_2_std   0.717675   1.000060  1.038333e-179
# mfcc_1_mean      -43.067787 -53.738009  1.079701e-176
# mfcc_8_mean        0.087171   0.070146  2.010693e-167
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 1002, Percentage = 33.57%
# Class 0: Count = 998, Percentage = 33.43%
# Class 2: Count = 985, Percentage = 33.00%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 257, Percentage = 34.40%
# Class 2: Count = 249, Percentage = 33.33%
# Class 1: Count = 241, Percentage = 32.26%
# Reduced variable features from initial count to 50.
# Reduced features based on correlation threshold of 0.8
#                                  0          2          1   p_value
# chroma_11_std             0.001628   0.001748   0.001668  0.044168
# delta chroma_11_std       0.002246   0.002415   0.002295  0.045552
# lib_mfcc_3_avg           26.095100  25.825932  25.808102  0.062394
# root_mean_square_energy   0.821051   0.775390   0.776354  0.073149
# chroma_5_std              0.017002   0.018030   0.017472  0.073609
# delta chroma_1_std        0.000399   0.000426   0.000403  0.084308
# chroma_1_std              0.000288   0.000307   0.000291  0.091696
# spectral_centroid_std     0.030714   0.031734   0.031416  0.093998
# chroma_3_std              0.008628   0.009212   0.008879  0.095618
# spectral_entropy_std      0.024439   0.026156   0.025198  0.109537
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2561, Percentage = 38.16%
# Class 2: Count = 2152, Percentage = 32.06%
# Class 1: Count = 1999, Percentage = 29.78%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 631, Percentage = 37.60%
# Class 1: Count = 541, Percentage = 32.24%
# Class 2: Count = 506, Percentage = 30.15%
# Reduced variable features from initial count to 45.
# Reduced features based on correlation threshold of 0.8
#                                 2          0          1       p_value
# delta chroma_7_std       0.049994   0.044451   0.044236  6.182970e-14
# spectral_centroid_mean   0.048252   0.044726   0.044092  7.332221e-14
# lib_mfcc_7_avg          10.527913  10.768692  10.793618  1.178328e-13
# spectral_centroid_std    0.033068   0.030842   0.031381  1.440884e-13
# chroma_7_std             0.036668   0.032784   0.032633  1.443210e-13
# spectral_spread_mean     0.114785   0.108805   0.106315  1.535929e-13
# delta chroma_5_std       0.028083   0.025070   0.025116  1.771038e-13
# chroma_5_std             0.020670   0.018541   0.018577  3.229023e-13
# lib_mfcc_9_avg           8.305123   8.460924   8.520690  4.471255e-13
# delta chroma_3_std       0.013562   0.011986   0.012182  2.604335e-12
#
# PROCESSING DATASET  3
# No columns with NaN values found.
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3394, Percentage = 50.74%
# Class 0: Count = 3295, Percentage = 49.26%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 852, Percentage = 50.93%
# Class 1: Count = 821, Percentage = 49.07%
# Reduced variable features from initial count to 48.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 1007, Percentage = 33.91%
# Class 1: Count = 993, Percentage = 33.43%
# Class 2: Count = 970, Percentage = 32.66%
# -Test distribution-
# Counts and Percentages:
# Class 2: Count = 259, Percentage = 34.86%
# Class 0: Count = 242, Percentage = 32.57%
# Class 1: Count = 242, Percentage = 32.57%
# Reduced variable features from initial count to 47.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2570, Percentage = 38.42%
# Class 2: Count = 2120, Percentage = 31.69%
# Class 1: Count = 1999, Percentage = 29.88%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 622, Percentage = 37.18%
# Class 2: Count = 528, Percentage = 31.56%
# Class 1: Count = 523, Percentage = 31.26%
# Reduced variable features from initial count to 49.
# Reduced features based on correlation threshold of 0.8
#
# PROCESSING DATASET  4
# No columns with NaN values found.
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3394, Percentage = 50.74%
# Class 0: Count = 3295, Percentage = 49.26%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 852, Percentage = 50.93%
# Class 1: Count = 821, Percentage = 49.07%
# Reduced variable features from initial count to 48.
# Reduced features based on correlation threshold of 0.8
#                           0          1        p_value
# mfcc_1_std        15.420095  22.152635  2.350091e-204
# mfcc_2_std         0.525291   0.745020  9.918619e-203
# mfcc_2_mean        1.888856   1.516630  2.186149e-189
# delta mfcc_1_std  20.767961  29.596046  4.081181e-186
# delta mfcc_2_std   0.716534   1.000642  8.973147e-184
# mfcc_4_mean        0.334685   0.270271  2.816353e-183
# mfcc_6_mean        0.160148   0.129038  1.552175e-181
# mfcc_3_mean        0.235893   0.190567  4.143878e-180
# mfcc_1_mean      -42.967170 -53.446919  2.469814e-175
# mfcc_8_mean        0.087352   0.070636  5.281282e-165
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 1007, Percentage = 33.91%
# Class 1: Count = 993, Percentage = 33.43%
# Class 2: Count = 970, Percentage = 32.66%
# -Test distribution-
# Counts and Percentages:
# Class 2: Count = 259, Percentage = 34.86%
# Class 0: Count = 242, Percentage = 32.57%
# Class 1: Count = 242, Percentage = 32.57%
# Reduced variable features from initial count to 47.
# Reduced features based on correlation threshold of 0.8
#                                  1          2          0   p_value
# delta chroma_11_std       0.002279   0.002419   0.002284  0.074853
# chroma_11_std             0.001652   0.001749   0.001660  0.087699
# chroma_5_std              0.017150   0.018078   0.017419  0.099979
# spectral_centroid_std     0.031012   0.032001   0.031324  0.100747
# delta chroma_1_std        0.000402   0.000425   0.000401  0.127592
# delta chroma_5_std        0.023193   0.024372   0.023468  0.138535
# chroma_7_std              0.029758   0.031368   0.030372  0.140458
# lib_mfcc_3_avg           26.102055  25.914446  25.854143  0.141840
# chroma_1_std              0.000291   0.000306   0.000290  0.145890
# root_mean_square_energy   0.816939   0.791267   0.773305  0.150621
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2570, Percentage = 38.42%
# Class 2: Count = 2120, Percentage = 31.69%
# Class 1: Count = 1999, Percentage = 29.88%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 622, Percentage = 37.18%
# Class 2: Count = 528, Percentage = 31.56%
# Class 1: Count = 523, Percentage = 31.26%
# Reduced variable features from initial count to 49.
# Reduced features based on correlation threshold of 0.8
#                                 2          0          1       p_value
# lib_mfcc_7_avg          10.516035  10.771236  10.790774  1.515754e-14
# lib_mfcc_9_avg           8.302979   8.449220   8.520979  6.704931e-13
# spectral_centroid_mean   0.048237   0.044935   0.044247  7.798461e-13
# spectral_spread_mean     0.114847   0.109315   0.106701  1.165185e-12
# delta chroma_7_std       0.049895   0.044768   0.044583  5.540267e-12
# chroma_7_std             0.036581   0.033039   0.032861  1.401801e-11
# delta chroma_5_std       0.028013   0.025227   0.025339  2.080040e-11
# delta chroma_3_std       0.013579   0.012035   0.012295  3.594329e-11
# chroma_5_std             0.020616   0.018668   0.018725  3.874251e-11
# chroma_7_mean            0.019064   0.016515   0.016025  6.885859e-11
#
# PROCESSING DATASET  5
# Removing columns with NaN values: ['kurtosis', 'skewness']
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3395, Percentage = 50.58%
# Class 0: Count = 3317, Percentage = 49.42%
# -Test distribution-
# Counts and Percentages:
# Class 1: Count = 846, Percentage = 50.42%
# Class 0: Count = 832, Percentage = 49.58%
# Reduced variable features from initial count to 44.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 1002, Percentage = 33.57%
# Class 0: Count = 998, Percentage = 33.43%
# Class 2: Count = 985, Percentage = 33.00%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 257, Percentage = 34.40%
# Class 2: Count = 249, Percentage = 33.33%
# Class 1: Count = 241, Percentage = 32.26%
# Reduced variable features from initial count to 48.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2561, Percentage = 38.16%
# Class 2: Count = 2152, Percentage = 32.06%
# Class 1: Count = 1999, Percentage = 29.78%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 631, Percentage = 37.60%
# Class 1: Count = 541, Percentage = 32.24%
# Class 2: Count = 506, Percentage = 30.15%
# Reduced variable features from initial count to 46.
# Reduced features based on correlation threshold of 0.8
#
# PROCESSING DATASET  6
# Removing columns with NaN values: ['kurtosis', 'skewness']
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3395, Percentage = 50.58%
# Class 0: Count = 3317, Percentage = 49.42%
# -Test distribution-
# Counts and Percentages:
# Class 1: Count = 846, Percentage = 50.42%
# Class 0: Count = 832, Percentage = 49.58%
# Reduced variable features from initial count to 44.
# Reduced features based on correlation threshold of 0.8
#                           1          0        p_value
# mfcc_1_std        15.449215  22.115462  1.682578e-198
# mfcc_2_std         0.526063   0.744023  1.965043e-197
# mfcc_2_mean        1.884292   1.506518  4.066107e-190
# mfcc_4_mean        0.333912   0.268655  1.855939e-183
# delta mfcc_1_std  20.811778  29.568298  1.160869e-181
# mfcc_3_mean        0.235375   0.189378  2.659541e-180
# mfcc_6_mean        0.159752   0.128396  3.019783e-180
# delta mfcc_2_std   0.717675   1.000060  1.037014e-179
# mfcc_1_mean      -43.074819 -53.747489  9.463612e-177
# mfcc_8_mean        0.087171   0.070147  2.009889e-167
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 1002, Percentage = 33.57%
# Class 0: Count = 998, Percentage = 33.43%
# Class 2: Count = 985, Percentage = 33.00%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 257, Percentage = 34.40%
# Class 2: Count = 249, Percentage = 33.33%
# Class 1: Count = 241, Percentage = 32.26%
# Reduced variable features from initial count to 48.
# Reduced features based on correlation threshold of 0.8
#                                0          2          1   p_value
# chroma_11_std           0.001628   0.001748   0.001668  0.044168
# delta chroma_11_std     0.002246   0.002415   0.002295  0.045552
# lib_mfcc_3_avg         27.505617  27.117931  27.090685  0.053232
# chroma_5_std            0.017002   0.018030   0.017472  0.073609
# delta chroma_1_std      0.000399   0.000426   0.000403  0.084308
# chroma_1_std            0.000288   0.000307   0.000291  0.091696
# spectral_centroid_std   0.030714   0.031734   0.031416  0.093998
# chroma_3_std            0.008628   0.009212   0.008879  0.095617
# spectral_entropy_std    0.024439   0.026156   0.025198  0.109537
# delta chroma_5_std      0.023000   0.024303   0.023519  0.111720
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2561, Percentage = 38.16%
# Class 2: Count = 2152, Percentage = 32.06%
# Class 1: Count = 1999, Percentage = 29.78%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 631, Percentage = 37.60%
# Class 1: Count = 541, Percentage = 32.24%
# Class 2: Count = 506, Percentage = 30.15%
# Reduced variable features from initial count to 46.
# Reduced features based on correlation threshold of 0.8
#                                 2          0          1       p_value
# lib_mfcc_7_avg          11.284888  11.733057  11.528728  7.811814e-20
# lib_mfcc_9_avg           9.058169   9.397272   9.233020  1.018831e-17
# lib_mfcc_8_avg          10.098988  10.449526  10.264671  1.770617e-15
# delta chroma_7_std       0.049994   0.044451   0.044236  6.182947e-14
# spectral_centroid_mean   0.048252   0.044726   0.044092  7.332222e-14
# spectral_centroid_std    0.033068   0.030842   0.031381  1.440886e-13
# chroma_7_std             0.036668   0.032784   0.032633  1.443205e-13
# spectral_spread_mean     0.114785   0.108805   0.106315  1.535929e-13
# delta chroma_5_std       0.028083   0.025070   0.025116  1.771031e-13
# chroma_5_std             0.020670   0.018541   0.018577  3.229013e-13
#
# PROCESSING DATASET  7
# No columns with NaN values found.
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3394, Percentage = 50.74%
# Class 0: Count = 3295, Percentage = 49.26%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 852, Percentage = 50.93%
# Class 1: Count = 821, Percentage = 49.07%
# Reduced variable features from initial count to 46.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 1007, Percentage = 33.91%
# Class 1: Count = 993, Percentage = 33.43%
# Class 2: Count = 970, Percentage = 32.66%
# -Test distribution-
# Counts and Percentages:
# Class 2: Count = 259, Percentage = 34.86%
# Class 0: Count = 242, Percentage = 32.57%
# Class 1: Count = 242, Percentage = 32.57%
# Reduced variable features from initial count to 44.
# Reduced features based on correlation threshold of 0.8
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2570, Percentage = 38.42%
# Class 2: Count = 2120, Percentage = 31.69%
# Class 1: Count = 1999, Percentage = 29.88%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 622, Percentage = 37.18%
# Class 2: Count = 528, Percentage = 31.56%
# Class 1: Count = 523, Percentage = 31.26%
# Reduced variable features from initial count to 47.
# Reduced features based on correlation threshold of 0.8
#
# PROCESSING DATASET  8
# No columns with NaN values found.
#
# # Research Question:  1
# -Train distribution-
# Counts and Percentages:
# Class 1: Count = 3394, Percentage = 50.74%
# Class 0: Count = 3295, Percentage = 49.26%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 852, Percentage = 50.93%
# Class 1: Count = 821, Percentage = 49.07%
# Reduced variable features from initial count to 46.
# Reduced features based on correlation threshold of 0.8
#                           0          1        p_value
# mfcc_1_std        15.416838  22.146003  2.646781e-204
# mfcc_2_std         0.525290   0.745021  9.891848e-203
# mfcc_2_mean        1.888856   1.516630  2.184455e-189
# delta mfcc_1_std  20.763484  29.587048  4.499103e-186
# delta mfcc_2_std   0.716534   1.000642  8.950038e-184
# mfcc_4_mean        0.334685   0.270270  2.790184e-183
# mfcc_6_mean        0.160148   0.129038  1.549882e-181
# mfcc_3_mean        0.235894   0.190567  4.109378e-180
# mfcc_1_mean      -42.974151 -53.456395  2.173009e-175
# mfcc_8_mean        0.087352   0.070636  5.356263e-165
#
# # Research Question:  2
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 1007, Percentage = 33.91%
# Class 1: Count = 993, Percentage = 33.43%
# Class 2: Count = 970, Percentage = 32.66%
# -Test distribution-
# Counts and Percentages:
# Class 2: Count = 259, Percentage = 34.86%
# Class 0: Count = 242, Percentage = 32.57%
# Class 1: Count = 242, Percentage = 32.57%
# Reduced variable features from initial count to 44.
# Reduced features based on correlation threshold of 0.8
#                                1          2          0   p_value
# delta chroma_11_std     0.002279   0.002419   0.002284  0.074853
# chroma_11_std           0.001652   0.001749   0.001660  0.087699
# chroma_5_std            0.017150   0.018078   0.017419  0.099979
# spectral_centroid_std   0.031012   0.032001   0.031324  0.100747
# delta chroma_1_std      0.000402   0.000425   0.000401  0.127592
# delta chroma_5_std      0.023193   0.024372   0.023468  0.138535
# chroma_7_std            0.029758   0.031368   0.030372  0.140458
# chroma_1_std            0.000291   0.000306   0.000290  0.145890
# chroma_10_std           0.000345   0.000363   0.000346  0.167406
# lib_mfcc_3_avg         27.515858  27.264891  27.176241  0.168311
#
# # Research Question:  5
# -Train distribution-
# Counts and Percentages:
# Class 0: Count = 2570, Percentage = 38.42%
# Class 2: Count = 2120, Percentage = 31.69%
# Class 1: Count = 1999, Percentage = 29.88%
# -Test distribution-
# Counts and Percentages:
# Class 0: Count = 622, Percentage = 37.18%
# Class 2: Count = 528, Percentage = 31.56%
# Class 1: Count = 523, Percentage = 31.26%
# Reduced variable features from initial count to 47.
# Reduced features based on correlation threshold of 0.8
#                                 2          0          1       p_value
# lib_mfcc_7_avg          11.270679  11.729932  11.517247  1.666365e-20
# lib_mfcc_9_avg           9.055580   9.379057   9.226300  3.016026e-16
# lib_mfcc_8_avg          10.091898  10.439283  10.256968  2.733032e-15
# lib_mfcc_5_avg          16.456202  17.005356  16.697735  4.263622e-14
# lib_mfcc_6_avg          13.704960  14.136619  13.908072  8.658430e-14
# spectral_centroid_mean   0.048237   0.044935   0.044247  7.798463e-13
# spectral_spread_mean     0.114847   0.109315   0.106701  1.165186e-12
# delta chroma_7_std       0.049895   0.044768   0.044583  5.540247e-12
# chroma_7_std             0.036581   0.033039   0.032861  1.401797e-11
# delta chroma_5_std       0.028013   0.025227   0.025339  2.080028e-11

# %% [markdown]
# # RQX

# %%
# %%time

results = {}  # Initialize an empty dictionary to store results

for ds in [1,2,3,4,5,7]:  # For each dataset
    print(f"Now processing Dataset {ds}...")  # Print the current dataset being processed
    results[ds] = {}  # Initialize a nested dictionary for each dataset
    for rq in [1, 2]:  # For each research question
        print(f"  Processing RQ {rq} within Dataset {ds}...")  # Print the current RQ being processed
        # Assuming datasets is a predefined structure with your data
        train_df, test_df = datasets[ds][rq]
        experiment = Experiment(train_df, test_df, 'target')
        experiment.run_all_models(param.PARAMETER_GRID)
        
        # Store the results of the experiment, along with the dataset and RQ identifiers
        results[ds][rq] = experiment.results
# Out:
# Now processing Dataset 1...
#   Processing RQ 1 within Dataset 1...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:10
#
# File ~\Documents\GitHub\Plant-Reactivity-Analysis\src\PlantReactivityAnalysis\models\experiment.py:20, in Experiment.__init__(self, train_df, test_df, label_column)
#      18 def __init__(self, train_df, test_df, label_column):
# ---> 20     assert set(train_df.columns) == set(test_df.columns), \
#      21         "Training and testing data must have the same columns"
#      22     assert set(train_df[label_column].unique()) == set(test_df[label_column].unique()), \
#      23         "Training and testing labels must contain the same classes"
#      25     self.train_features = train_df.drop(columns=[label_column])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
# Prepare a list to hold all rows before creating the DataFrame
rows = []

# Iterate over the nested structure to access each experiment's results
for ds, rqs in results.items():
    for rq, experiments in rqs.items():
        for experiment_result in experiments:
            rows.append({
                'Dataset': ds,
                'RQ': rq,
                'Model': experiment_result['model_name'],
                'Parameter': experiment_result['parameters'],
                'F1 Score': experiment_result['f1'],
                'Accuracy': experiment_result['accuracy'],
                'Precision': experiment_result['precision'],
                'Recall': experiment_result['recall']
            })

# Convert the list of dictionaries into a DataFrame
df_results = pd.DataFrame(rows)

# Save the DataFrame to a CSV file
csv_file_path = "results_wshl11_ct08.csv"
df_results.to_csv(csv_file_path, index=False)
