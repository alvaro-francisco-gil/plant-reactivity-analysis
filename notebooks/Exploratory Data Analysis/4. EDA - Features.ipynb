# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from PlantReactivityAnalysis.features.features_dataset import FeaturesDataset

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Explore Features

# %% [markdown]
# ## Data import

# %%
norm_letters_signal_dataset_path= r"..\..\data\processed\feat_norm_letters_1_1_dataset.pkl"
dataset= FeaturesDataset.load(norm_letters_signal_dataset_path)

# %%
dataset.features.shape
# Out:
# (8390, 187)

# %%
dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter  lib_mfcc_1_avg  lib_mfcc_2_avg  \
# 0             1              A1      -85.835655       90.291260
# 1             1              G1      -96.628212       83.604851
# 2             1              D1     -109.998672       89.973495
# 3             1              A2      -83.306580       89.631935
# 4             1              G2      -65.591743       89.487083
#
#    lib_mfcc_3_avg  lib_mfcc_4_avg  lib_mfcc_5_avg  lib_mfcc_6_avg  \
# 0       27.150677       24.450397       17.381523       14.476572
# ...

# %%
dataset.prepare_dataset(drop_constant=False, drop_flatness_columns=False, drop_nan_columns=True)
# Out:
# Removing columns with NaN values: ['skewness', 'kurtosis']

# %%
dataset.features.shape
# Out:
# (8390, 185)

# %%
df= dataset.objective_features
corr_matrix = df.corr()

# %%
plt.figure(figsize=(100, 100))  # Adjust the figure size as necessary
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=.5)
plt.savefig('correlation_matrix_heatmap.png')
plt.show()
