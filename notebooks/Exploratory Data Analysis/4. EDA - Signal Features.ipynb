# %%
import sys
sys.path.append("../../src")

# %%
from features.features_dataset import FeaturesDataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Explore Features

# %% [markdown]
# ## Data import

# %%
norm_letters_signal_dataset_path= r"..\..\data\processed\feat_norm_letters_1_1_dataset.pkl"
dataset= FeaturesDataset.load(norm_letters_signal_dataset_path)

# %%
dataset.features.shape
# Out:
# (8390, 187)

# %%
dataset.features.head()
# Out:
#    id_measurement  id_performance    datetime  plant  generation  \
# 0               1               1  2023-04-29  salad           1
# 1               1               1  2023-04-29  salad           1
# 2               1               1  2023-04-29  salad           1
# 3               1               1  2023-04-29  salad           1
# 4               1               1  2023-04-29  salad           1
#
#    num_eurythmy eurythmy_letter  lib_mfcc_1_avg  lib_mfcc_2_avg  \
# 0             1              A1      -85.835655       90.291260
# 1             1              G1      -96.628212       83.604851
# 2             1              D1     -109.998672       89.973495
# 3             1              A2      -83.306580       89.631935
# 4             1              G2      -65.591743       89.487083
#
#    lib_mfcc_3_avg  ...  flatness_ratio_100  hjorth_mobility  \
# 0       27.150677  ...            0.998622         0.000020
# 1       26.647131  ...            0.992111         0.000035
# ...

# %%
#dataset.drop_columns(['skewness', 'kurtosis'])

# %%
dataset.replace_ndarray_with_mean()

# %%
dataset.rename_column(initial_name= 'segment', final_name= 'eurythmy_letter')

# %%
dataset.objective_features.dtypes
# Out:
# lib_mfcc_1_avg                  float64
# lib_mfcc_2_avg                  float64
# lib_mfcc_3_avg                  float64
# lib_mfcc_4_avg                  float64
# lib_mfcc_5_avg                  float64
# lib_mfcc_6_avg                  float64
# lib_mfcc_7_avg                  float64
# lib_mfcc_8_avg                  float64
# lib_mfcc_9_avg                  float64
# lib_mfcc_10_avg                 float64
# lib_mfcc_11_avg                 float64
# lib_mfcc_12_avg                 float64
# lib_mfcc_13_avg                 float64
# lib_mfcc_1_std                  float64
# lib_mfcc_2_std                  float64
# lib_mfcc_3_std                  float64
# lib_mfcc_4_std                  float64
# lib_mfcc_5_std                  float64
# lib_mfcc_6_std                  float64
# lib_mfcc_7_std                  float64
# lib_mfcc_8_std                  float64
# lib_mfcc_9_std                  float64
# lib_mfcc_10_std                 float64
# ...

# %%
klk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 klk
#
# NameError: name 'klk' is not defined

# %%
# Save the dataset
feat_norm_letters_dataset_path= r"..\..\data\processed\feat_norm_letters_1_1_dataset_mean.pkl"
dataset.save(feat_norm_letters_dataset_path)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df= dataset.objective_features

corr_matrix = df.corr()

# Assuming corr_matrix is already defined

plt.figure(figsize=(100, 80))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=.5)

# Save the figure
#plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')

# If you still want to display the plot in the notebook after saving it, you can call plt.show() afterward
plt.show()

# %%
corr_matrix = dataset.objective_features.corr()

# Print the correlation matrix
print(corr_matrix)

# If you want to visualize the correlation matrix
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar=True)
plt.show()
